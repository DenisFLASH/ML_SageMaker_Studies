# %% [markdown]
# # Plagiarism Detection, Feature Engineering
#
# In this project, you will be tasked with building a plagiarism detector that examines an answer text file and performs binary classification; labeling that file as either plagiarized or not, depending on how similar that text file is to a provided, source text.
#
# Your first task will be to create some features that can then be used to train a classification model. This task will be broken down into a few discrete steps:
#
# * Clean and pre-process the data.
# * Define features for comparing the similarity of an answer text and a source text, and extract similarity features.
# * Select "good" features, by analyzing the correlations between different features.
# * Create train/test `.csv` files that hold the relevant features and class labels for train/test data points.
#
# In the _next_ notebook, Notebook 3, you'll use the features and `.csv` files you create in _this_ notebook to train a binary classification model in a SageMaker notebook instance.
#
# You'll be defining a few different similarity features, as outlined in [this paper](https://s3.amazonaws.com/video.udacity-data.com/topher/2019/January/5c412841_developing-a-corpus-of-plagiarised-short-answers/developing-a-corpus-of-plagiarised-short-answers.pdf), which should help you build a robust plagiarism detector!
#
# To complete this notebook, you'll have to complete all given exercises and answer all the questions in this notebook.
# > All your tasks will be clearly labeled **EXERCISE** and questions as **QUESTION**.
#
# It will be up to you to decide on the features to include in your final training and test data.
#
# ---

# %% [markdown]
# ## Read in the Data
#
# The cell below will download the necessary, project data and extract the files into the folder `data/`.
#
# This data is a slightly modified version of a dataset created by Paul Clough (Information Studies) and Mark Stevenson (Computer Science), at the University of Sheffield. You can read all about the data collection and corpus, at [their university webpage](https://ir.shef.ac.uk/cloughie/resources/plagiarism_corpus.html).
#
# > **Citation for data**: Clough, P. and Stevenson, M. Developing A Corpus of Plagiarised Short Answers, Language Resources and Evaluation: Special Issue on Plagiarism and Authorship Analysis, In Press. [Download]

# %%
# NOTE:
# you only need to run this cell if you have not yet downloaded the data
# otherwise you may skip this cell or comment it out

# !wget https://s3.amazonaws.com/video.udacity-data.com/topher/2019/January/5c4147f9_data/data.zip
# !unzip data

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# This plagiarism dataset is made of multiple text files; each of these files has characteristics that are is summarized in a `.csv` file named `file_information.csv`, which we can read in using `pandas`.

# %%
csv_file = 'data/file_information.csv'
plagiarism_df = pd.read_csv(csv_file)

# print out the first few rows of data info
plagiarism_df.head()
# Out:
#              File Task Category
# 0  g0pA_taska.txt    a      non
# 1  g0pA_taskb.txt    b      cut
# 2  g0pA_taskc.txt    c    light
# 3  g0pA_taskd.txt    d    heavy
# 4  g0pA_taske.txt    e      non

# %% [markdown]
# ## Types of Plagiarism
#
# Each text file is associated with one **Task** (task A-E) and one **Category** of plagiarism, which you can see in the above DataFrame.
#
# ###  Tasks, A-E
#
# Each text file contains an answer to one short question; these questions are labeled as tasks A-E. For example, Task A asks the question: "What is inheritance in object oriented programming?"
#
# ### Categories of plagiarism
#
# Each text file has an associated plagiarism label/category:
#
# **1. Plagiarized categories: `cut`, `light`, and `heavy`.**
# * These categories represent different levels of plagiarized answer texts. `cut` answers copy directly from a source text, `light` answers are based on the source text but include some light rephrasing, and `heavy` answers are based on the source text, but *heavily* rephrased (and will likely be the most challenging kind of plagiarism to detect).
#
# **2. Non-plagiarized category: `non`.**
# * `non` indicates that an answer is not plagiarized; the Wikipedia source text is not used to create this answer.
#
# **3. Special, source text category: `orig`.**
# * This is a specific category for the original, Wikipedia source text. We will use these files only for comparison purposes.

# %% [markdown]
# ---
# ## Pre-Process the Data
#
# In the next few cells, you'll be tasked with creating a new DataFrame of desired information about all of the files in the `data/` directory. This will prepare the data for feature extraction and for training a binary, plagiarism classifier.

# %% [markdown]
# ### EXERCISE: Convert categorical to numerical data
#
# You'll notice that the `Category` column in the data, contains string or categorical values, and to prepare these for feature extraction, we'll want to convert these into numerical values. Additionally, our goal is to create a binary classifier and so we'll need a binary class label that indicates whether an answer text is plagiarized (1) or not (0). Complete the below function `numerical_dataframe` that reads in a `file_information.csv` file by name, and returns a *new* DataFrame with a numerical `Category` column and a new `Class` column that labels each answer as plagiarized or not.
#
# Your function should return a new DataFrame with the following properties:
#
# * 4 columns: `File`, `Task`, `Category`, `Class`. The `File` and `Task` columns can remain unchanged from the original `.csv` file.
# * Convert all `Category` labels to numerical labels according to the following rules (a higher value indicates a higher degree of plagiarism):
#     * 0 = `non`
#     * 1 = `heavy`
#     * 2 = `light`
#     * 3 = `cut`
#     * -1 = `orig`, this is a special value that indicates an original file.
# * For the new `Class` column
#     * Any answer text that is not plagiarized (`non`) should have the class label `0`.
#     * Any plagiarized answer texts should have the class label `1`.
#     * And any `orig` texts will have a special label `-1`.
#
# ### Expected output
#
# After running your function, you should get a DataFrame with rows that looks like the following:
# ```
#
#         File	     Task  Category  Class
# 0	g0pA_taska.txt	a	  0   	0
# 1	g0pA_taskb.txt	b	  3   	1
# 2	g0pA_taskc.txt	c	  2   	1
# 3	g0pA_taskd.txt	d	  1   	1
# 4	g0pA_taske.txt	e	  0	   0
# ...
# ...
# 99   orig_taske.txt    e     -1      -1
#
# ```

# %%
# Read in a csv file and return a transformed dataframe
def numerical_dataframe(csv_file='data/file_information.csv'):
    '''Reads in a csv file which is assumed to have `File`, `Category` and `Task` columns.
       This function does two things: 
       1) converts `Category` column values to numerical values 
       2) Adds a new, numerical `Class` label column.
       The `Class` column will label plagiarized answers as 1 and non-plagiarized as 0.
       Source texts have a special label, -1.
       :param csv_file: The directory for the file_information.csv file
       :return: A dataframe with numerical categories and a new `Class` label column'''
    
    # your code here
    
    df = pd.read_csv(csv_file)
    mapping_category = {
        "non": 0, 
        "heavy": 1,
        "light": 2,
        "cut": 3,
        "orig": -1
    }
    
    df["Category"] = df["Category"].map(mapping_category)
    df["Class"] = np.sign(df["Category"])
    
    return df

# %% [markdown]
# ### Test cells
#
# Below are a couple of test cells. The first is an informal test where you can check that your code is working as expected by calling your function and printing out the returned result.
#
# The **second** cell below is a more rigorous test cell. The goal of a cell like this is to ensure that your code is working as expected, and to form any variables that might be used in _later_ tests/code, in this case, the data frame, `transformed_df`.
#
# > The cells in this notebook should be run in chronological order (the order they appear in the notebook). This is especially important for test cells.
#
# Often, later cells rely on the functions, imports, or variables defined in earlier cells. For example, some tests rely on previous tests to work.
#
# These tests do not test all cases, but they are a great way to check that you are on the right track!

# %%
# informal testing, print out the results of a called function
# create new `transformed_df`
transformed_df = numerical_dataframe(csv_file ='data/file_information.csv')

# check work
# check that all categories of plagiarism have a class label = 1
transformed_df.head(10)
# Out:
#              File Task  Category  Class
# 0  g0pA_taska.txt    a         0      0
# 1  g0pA_taskb.txt    b         3      1
# 2  g0pA_taskc.txt    c         2      1
# 3  g0pA_taskd.txt    d         1      1
# 4  g0pA_taske.txt    e         0      0
# 5  g0pB_taska.txt    a         0      0
# 6  g0pB_taskb.txt    b         0      0
# 7  g0pB_taskc.txt    c         3      1
# 8  g0pB_taskd.txt    d         2      1
# 9  g0pB_taske.txt    e         1      1

# %%
transformed_df.loc[0]
# Out:
# File        g0pA_taska.txt
# Task                     a
# Category                 0
# Class                    0
# Name: 0, dtype: object

# %%
# test cell that creates `transformed_df`, if tests are passed

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

# importing tests
import problem_unittests as tests

# test numerical_dataframe function
tests.test_numerical_df(numerical_dataframe)

# if above test is passed, create NEW `transformed_df`
transformed_df = numerical_dataframe(csv_file ='data/file_information.csv')

# check work
print('\nExample data: ')
transformed_df.head()
# Out:
# Tests Passed!
#
# Example data:
#              File Task  Category  Class
# 0  g0pA_taska.txt    a         0      0
# 1  g0pA_taskb.txt    b         3      1
# 2  g0pA_taskc.txt    c         2      1
# 3  g0pA_taskd.txt    d         1      1
# 4  g0pA_taske.txt    e         0      0

# %% [markdown]
# ## Text Processing & Splitting Data
#
# Recall that the goal of this project is to build a plagiarism classifier. At it's heart, this task is a comparison text; one that looks at a given answer and a source text, compares them and predicts whether an answer has plagiarized from the source. To effectively do this comparison, and train a classifier we'll need to do a few more things: pre-process all of our text data and prepare the text files (in this case, the 95 answer files and 5 original source files) to be easily compared, and split our data into a `train` and `test` set that can be used to train a classifier and evaluate it, respectively.
#
# To this end, you've been provided code that adds  additional information to your `transformed_df` from above. The next two cells need not be changed; they add two additional columns to the `transformed_df`:
#
# 1. A `Text` column; this holds all the lowercase text for a `File`, with extraneous punctuation removed.
# 2. A `Datatype` column; this is a string value `train`, `test`, or `orig` that labels a data point as part of our train or test set
#
# The details of how these additional columns are created can be found in the `helpers.py` file in the project directory. You're encouraged to read through that file to see exactly how text is processed and how data is split.
#
# Run the cells below to get a `complete_df` that has all the information you need to proceed with plagiarism detection and feature engineering.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
import helpers 

# create a text column 
text_df = helpers.create_text_column(transformed_df)
text_df.head()
# Out:
#              File Task  Category  Class  \
# 0  g0pA_taska.txt    a         0      0
# 1  g0pA_taskb.txt    b         3      1
# 2  g0pA_taskc.txt    c         2      1
# 3  g0pA_taskd.txt    d         1      1
# 4  g0pA_taske.txt    e         0      0
#
#                                                 Text
# 0  inheritance is a basic concept of object orien...
# 1  pagerank is a link analysis algorithm used by ...
# 2  the vector space model also called term vector...
# 3  bayes theorem was names after rev thomas bayes...
# 4  dynamic programming is an algorithm design tec...

# %%
# after running the cell above
# check out the processed text for a single file, by row index
row_idx = 0 # feel free to change this index

sample_text = text_df.iloc[0]['Text']

print('Sample processed text:\n\n', sample_text)
# Out:
# Sample processed text:
#
#  inheritance is a basic concept of object oriented programming where the basic idea is to create new classes that add extra detail to existing classes this is done by allowing the new classes to reuse the methods and variables of the existing classes and new methods and classes are added to specialise the new class inheritance models the is kind of relationship between entities or objects  for example postgraduates and undergraduates are both kinds of student this kind of relationship can be visualised as a tree structure where student would be the more general root node and both postgraduate and undergraduate would be more specialised extensions of the student node or the child nodes  in this relationship student would be known as the superclass or parent class whereas  postgraduate would be known as the subclass or child class because the postgraduate class extends the student class  inheritance can occur on several layers where if visualised would display a larger tree structure for example we could further extend the postgraduate node by adding two extra extended classes to it called  msc student and phd student as both these types of student are kinds of postgraduate student this would mean that both the msc student and phd student classes would inherit methods and variables from both the postgraduate and student classes

# %% [markdown]
# ## Split data into training and test sets
#
# The next cell will add a `Datatype` column to a given DataFrame to indicate if the record is:
# * `train` - Training data, for model training.
# * `test` - Testing data, for model evaluation.
# * `orig` - The task's original answer from wikipedia.
#
# ### Stratified sampling
#
# The given code uses a helper function which you can view in the `helpers.py` file in the main project directory. This implements [stratified random sampling](https://en.wikipedia.org/wiki/Stratified_sampling) to randomly split data by task & plagiarism amount. Stratified sampling ensures that we get training and test data that is fairly evenly distributed across task & plagiarism combinations. Approximately 26% of the data is held out for testing and 74% of the data is used for training.
#
# The function **train_test_dataframe** takes in a DataFrame that it assumes has `Task` and `Category` columns, and, returns a modified frame that indicates which `Datatype` (train, test, or orig) a file falls into. This sampling will change slightly based on a passed in *random_seed*. Due to a small sample size, this stratified random sampling will provide more stable results for a binary plagiarism classifier. Stability here is smaller *variance* in the accuracy of classifier, given a random seed.

# %%
random_seed = 1 # can change; set for reproducibility

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
import helpers

# create new df with Datatype (train, test, orig) column
# pass in `text_df` from above to create a complete dataframe, with all the information you need
complete_df = helpers.train_test_dataframe(text_df, random_seed=random_seed)

# check results
complete_df.head(10)
# Out:
#              File Task  Category  Class  \
# 0  g0pA_taska.txt    a         0      0
# 1  g0pA_taskb.txt    b         3      1
# 2  g0pA_taskc.txt    c         2      1
# 3  g0pA_taskd.txt    d         1      1
# 4  g0pA_taske.txt    e         0      0
# 5  g0pB_taska.txt    a         0      0
# 6  g0pB_taskb.txt    b         0      0
# 7  g0pB_taskc.txt    c         3      1
# 8  g0pB_taskd.txt    d         2      1
# 9  g0pB_taske.txt    e         1      1
#
#                                                 Text Datatype
# 0  inheritance is a basic concept of object orien...    train
# 1  pagerank is a link analysis algorithm used by ...     test
# 2  the vector space model also called term vector...    train
# 3  bayes theorem was names after rev thomas bayes...    train
# 4  dynamic programming is an algorithm design tec...    train
# 5  inheritance is a basic concept in object orien...    train
# 6  pagerank pr refers to both the concept and the...    train
# 7  vector space model is an algebraic model for r...     test
# 8  bayes theorem relates the conditional and marg...    train
# 9  dynamic programming is a method for solving ma...     test

# %%
complete_df[complete_df["Datatype"] == "test"].iloc[12]
# Out:
# File                                           g2pB_taskc.txt
# Task                                                        c
# Category                                                    1
# Class                                                       1
# Text        a vector space model is an algebraic model for...
# Datatype                                                 test
# Name: 47, dtype: object

# %%
complete_df[(complete_df["Datatype"] == "orig") & (complete_df["Task"] == "c")]
# Out:
#               File Task  Category  Class  \
# 97  orig_taskc.txt    c        -1     -1
#
#                                                  Text Datatype
# 97  vector space model or term vector model is an ...     orig

# %% [markdown]
# # Determining Plagiarism
#
# Now that you've prepared this data and created a `complete_df` of information, including the text and class associated with each file, you can move on to the task of extracting similarity features that will be useful for plagiarism classification.
#
# > Note: The following code exercises, assume that the `complete_df` as it exists now, will **not** have its existing columns modified.
#
# The `complete_df` should always include the columns: `['File', 'Task', 'Category', 'Class', 'Text', 'Datatype']`. You can add additional columns, and you can create any new DataFrames you need by copying the parts of the `complete_df` as long as you do not modify the existing values, directly.
#
# ---

# %% [markdown]
# # Similarity Features
#
# One of the ways we might go about detecting plagiarism, is by computing **similarity features** that measure how similar a given answer text is as compared to the original wikipedia source text (for a specific task, a-e). The similarity features you will use are informed by [this paper on plagiarism detection](https://s3.amazonaws.com/video.udacity-data.com/topher/2019/January/5c412841_developing-a-corpus-of-plagiarised-short-answers/developing-a-corpus-of-plagiarised-short-answers.pdf).
# > In this paper, researchers created features called **containment** and **longest common subsequence**.
#
# Using these features as input, you will train a model to distinguish between plagiarized and not-plagiarized text files.
#
# ## Feature Engineering
#
# Let's talk a bit more about the features we want to include in a plagiarism detection model and how to calculate such features. In the following explanations, I'll refer to a submitted text file as a **Student Answer Text (A)** and the original, wikipedia source file (that we want to compare that answer to) as the **Wikipedia Source Text (S)**.
#
# ### Containment
#
# Your first task will be to create **containment features**. To understand containment, let's first revisit a definition of [n-grams](https://en.wikipedia.org/wiki/N-gram). An *n-gram* is a sequential word grouping. For example, in a line like "bayes rule gives us a way to combine prior knowledge with new information," a 1-gram is just one word, like "bayes." A 2-gram might be "bayes rule" and a 3-gram might be "combine prior knowledge."
#
# > Containment is defined as the **intersection** of the n-gram word count of the Wikipedia Source Text (S) with the n-gram word count of the Student  Answer Text (S) *divided* by the n-gram word count of the Student Answer Text.
#
# $$ \frac{\sum{count(\text{ngram}_{A}) \cap count(\text{ngram}_{S})}}{\sum{count(\text{ngram}_{A})}} $$
#
# If the two texts have no n-grams in common, the containment will be 0, but if _all_ their n-grams intersect then the containment will be 1. Intuitively, you can see how having longer n-gram's in common, might be an indication of cut-and-paste plagiarism. In this project, it will be up to you to decide on the appropriate `n` or several `n`'s to use in your final model.
#
# ### EXERCISE: Create containment features
#
# Given the `complete_df` that you've created, you should have all the information you need to compare any Student  Answer Text (A) with its appropriate Wikipedia Source Text (S). An answer for task A should be compared to the source text for task A, just as answers to tasks B, C, D, and E should be compared to the corresponding original source text.
#
# In this exercise, you'll complete the function, `calculate_containment` which calculates containment based upon the following parameters:
# * A given DataFrame, `df` (which is assumed to be the `complete_df` from above)
# * An `answer_filename`, such as 'g0pB_taskd.txt'
# * An n-gram length, `n`
#
# ### Containment calculation
#
# The general steps to complete this function are as follows:
# 1. From *all* of the text files in a given `df`, create an array of n-gram counts; it is suggested that you use a [CountVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html) for this purpose.
# 2. Get the processed answer and source texts for the given `answer_filename`.
# 3. Calculate the containment between an answer and source text according to the following equation.
#
#     >$$ \frac{\sum{count(\text{ngram}_{A}) \cap count(\text{ngram}_{S})}}{\sum{count(\text{ngram}_{A})}} $$
#
# 4. Return that containment value.
#
# You are encouraged to write any helper functions that you need to complete the function below.

# %%
# original texts
origs = complete_df[complete_df["Datatype"] == "orig"]
orig_texts = {task: text for task, text in origs[["Task", "Text"]].values}
orig_texts["a"]
# Out:
# 'in object oriented programming inheritance is a way to form new classes instances of which are called objects using classes that have already been defined the inheritance concept was invented in 1967 for simula  the new classes known as derived classes take over or inherit attributes and behavior of the pre existing classes which are referred to as base classes or ancestor classes  it is intended to help reuse existing code with little or no modification  inheritance provides the support for representation by categorization in computer languages categorization is a powerful mechanism number of information processing crucial to human learning by means of generalization what is known about specific entities is applied to a wider group given a belongs relation can be established and cognitive economy less information needs to be stored about each specific entity only its particularities  inheritance is also sometimes called generalization because the is a relationships represent a hierarchy between classes of objects for instance a fruit is a generalization of apple  orange  mango and many others one can consider fruit to be an abstraction of apple orange etc conversely since apples are fruit i e  an apple is a fruit  apples may naturally inherit all the properties common to all fruit such as being a fleshy container for the seed of a plant  an advantage of inheritance is that modules with sufficiently similar interfaces can share a lot of code reducing the complexity of the program inheritance therefore has another view a dual called polymorphism which describes many pieces of code being controlled by shared control code inheritance is typically accomplished either by overriding replacing one or more methods exposed by ancestor or by adding new methods to those exposed by an ancestor  complex inheritance or inheritance used within a design that is not sufficiently mature may lead to the yo yo problem '

# %%
from sklearn.feature_extraction.text import CountVectorizer

def containment(ngram_array):
    ''' Containment is a measure of text similarity. It is the normalized, 
       intersection of ngram word counts in two texts.
       :param ngram_array: an array of ngram counts for an answer and source text.
       :return: a normalized containment value.'''
    
    a = ngram_array[0]
    s = ngram_array[1]
    total_common_ngrams = sum(np.minimum(a, s))
    answer_ngrams = sum(a)
    containment = total_common_ngrams / answer_ngrams
    print(f"common {n}-grams: {total_common_ngrams}, answer_ngrams={answer_ngrams}, containment {containment}")
    return containment


# Calculate the ngram containment for one answer file/source file pair in a df
def calculate_containment(df, n, answer_filename):
    '''Calculates the containment between a given answer text and its associated source text.
       This function creates a count of ngrams (of a size, n) for each text file in our data.
       Then calculates the containment by finding the ngram count for a given answer text, 
       and its associated source text, and calculating the normalized intersection of those counts.
       :param df: A dataframe with columns,
           'File', 'Task', 'Category', 'Class', 'Text', and 'Datatype'
       :param n: An integer that defines the ngram size
       :param answer_filename: A filename for an answer text in the df, ex. 'g0pB_taskd.txt'
       :return: A single containment value that represents the similarity
           between an answer text and its source text.
    '''
    
    row_idx = df[df["File"] == answer_filename].index[0]
    
    # calculate containment between {a_text} and {s_text} of the corresponding task
    a_text = df["Text"][row_idx]
    task = df["Task"][row_idx]
    s_text = orig_texts[task]

    #print(f"calculate containment between \n\n{a_text}\n\n and \n\n{s_text}")

    # instantiate an ngram counter
    counts = CountVectorizer(analyzer='word', ngram_range=(n,n))
    
    # create array of n-gram counts for the answer and source text
    ngrams = counts.fit_transform([a_text, s_text])

    # row = the 2 texts and column = indexed vocab terms
    ngram_array = ngrams.toarray()

    # calculate the containment itself
    containment_val = containment(ngrams.toarray())

    return containment_val

# %% [markdown]
# ### Test cells
#
# After you've implemented the containment function, you can test out its behavior.
#
# The cell below iterates through the first few files, and calculates the original category _and_ containment values for a specified n and file.
#
# >If you've implemented this correctly, you should see that the non-plagiarized have low or close to 0 containment values and that plagiarized examples have higher containment values, closer to 1.
#
# Note what happens when you change the value of n. I recommend applying your code to multiple files and comparing the resultant containment values. You should see that the highest containment values correspond to files with the highest category (`cut`) of plagiarism level.

# %%
# select a value for n
n = 2

# indices for first few files
test_indices = range(5)

# iterate through files and calculate containment
category_vals = []
containment_vals = []
for i in test_indices:
    # get level of plagiarism for a given file index
    category_vals.append(complete_df.loc[i, 'Category'])
    # calculate containment for given file and n
    filename = complete_df.loc[i, 'File']
    c = calculate_containment(complete_df, n, filename)
    containment_vals.append(c)

# print out result, does it make sense?
print('Original category values: \n', category_vals)
print()
print(str(n)+'-gram containment values: \n', containment_vals)
# Out:
# common 2-grams: 17, answer_ngrams=215, containment 0.07906976744186046
# common 2-grams: 193, answer_ngrams=196, containment 0.9846938775510204
# common 2-grams: 159, answer_ngrams=221, containment 0.7194570135746606
# common 2-grams: 50, answer_ngrams=186, containment 0.26881720430107525
# common 2-grams: 22, answer_ngrams=190, containment 0.11578947368421053
# Original category values:
#  [0, 3, 2, 1, 0]
#
# 2-gram containment values:
#  [0.07906976744186046, 0.9846938775510204, 0.7194570135746606, 0.26881720430107525, 0.11578947368421053]

# %%
# run this test cell
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# test containment calculation
# params: complete_df from before, and containment function
tests.test_containment(complete_df, calculate_containment)
# Out:
# common 2-grams: 104, answer_ngrams=191, containment 0.5445026178010471
# common 2-grams: 86, answer_ngrams=216, containment 0.39814814814814814
# common 2-grams: 2, answer_ngrams=214, containment 0.009345794392523364
# common 2-grams: 197, answer_ngrams=197, containment 1.0
# common 2-grams: 188, answer_ngrams=195, containment 0.9641025641025641
# common 2-grams: 193, answer_ngrams=222, containment 0.8693693693693694
# common 2-grams: 135, answer_ngrams=220, containment 0.6136363636363636
# common 2-grams: 111, answer_ngrams=187, containment 0.5935828877005348
# common 2-grams: 29, answer_ngrams=185, containment 0.15675675675675677
# expected=[0.39814814814814814, 1.0, 0.8693693693693694, 0.5935828877005348], got [0.39814814814814814, 1.0, 0.8693693693693694, 0.5935828877005348]
# expected=[0.009345794392523364, 0.9641025641025641, 0.6136363636363636, 0.15675675675675677], got [0.009345794392523364, 0.9641025641025641, 0.6136363636363636, 0.15675675675675677]

# %% [markdown]
# ### QUESTION 1: Why can we calculate containment features across *all* data (training & test), prior to splitting the DataFrame for modeling? That is, what about the containment calculation means that the test and training data do not influence each other?

# %% [markdown]
# **Answer:**
# Unlike bag-of-words, we don't have a common VOCABULARY here, thus no data leakage is happening here.
#
# Whether it is train or test set, answer texts are compared to the same set of original source texts (5 in this case, for tasks A-E). And then, each calculation of containment is independent. N-gram arrays are being calculated only for a given answer text, not for a global n-gram vocabulary across all answers.

# %% [markdown]
# ---
# ## Longest Common Subsequence
#
# Containment a good way to find overlap in word usage between two documents; it may help identify cases of cut-and-paste as well as paraphrased levels of plagiarism. Since plagiarism is a fairly complex task with varying levels, it's often useful to include other measures of similarity. The paper also discusses a feature called **longest common subsequence**.
#
# > The longest common subsequence is the longest string of words (or letters) that are *the same* between the Wikipedia Source Text (S) and the Student Answer Text (A). This value is also normalized by dividing by the total number of words (or letters) in the  Student Answer Text.
#
# In this exercise, we'll ask you to calculate the longest common subsequence of words between two texts.
#
# ### EXERCISE: Calculate the longest common subsequence
#
# Complete the function `lcs_norm_word`; this should calculate the *longest common subsequence* of words between a Student Answer Text and corresponding Wikipedia Source Text.
#
# It may be helpful to think of this in a concrete example. A Longest Common Subsequence (LCS) problem may look as follows:
# * Given two texts: text A (answer text) of length n, and string S (original source text) of length m. Our goal is to produce their longest common subsequence of words: the longest sequence of words that appear left-to-right in both texts (though the words don't have to be in continuous order).
# * Consider:
#     * A = "i think pagerank is a link analysis algorithm used by google that uses a system of weights attached to each element of a hyperlinked set of documents"
#     * S = "pagerank is a link analysis algorithm used by the google internet search engine that assigns a numerical weighting to each element of a hyperlinked set of documents"
#
# * In this case, we can see that the start of each sentence of fairly similar, having overlap in the sequence of words, "pagerank is a link analysis algorithm used by" before diverging slightly. Then we **continue moving left -to-right along both texts** until we see the next common sequence; in this case it is only one word, "google". Next we find "that" and "a" and finally the same ending "to each element of a hyperlinked set of documents".
# * Below, is a clear visual of how these sequences were found, sequentially, in each text.
#
# <img src='notebook_ims/common_subseq_words.png' width=40% />
#
# * Now, those words appear in left-to-right order in each document, sequentially, and even though there are some words in between, we count this as the longest common subsequence between the two texts.
# * If I count up each word that I found in common I get the value 20. **So, LCS has length 20**.
# * Next, to normalize this value, divide by the total length of the student answer; in this example that length is only 27. **So, the function `lcs_norm_word` should return the value `20/27` or about `0.7408`.**
#
# In this way, LCS is a great indicator of cut-and-paste plagiarism or if someone has referenced the same source text multiple times in an answer.

# %% [markdown]
# ### LCS, dynamic programming
#
# If you read through the scenario above, you can see that this algorithm depends on looking at two texts and comparing them word by word. You can solve this problem in multiple ways. First, it may be useful to `.split()` each text into lists of comma separated words to compare. Then, you can iterate through each word in the texts and compare them, adding to your value for LCS as you go.
#
# The method I recommend for implementing an efficient LCS algorithm is: using a matrix and dynamic programming. **Dynamic programming** is all about breaking a larger problem into a smaller set of subproblems, and building up a complete result without having to repeat any subproblems.
#
# This approach assumes that you can split up a large LCS task into a combination of smaller LCS tasks. Let's look at a simple example that compares letters:
#
# * A = "ABCD"
# * S = "BD"
#
# We can see right away that the longest subsequence of _letters_ here is 2 (B and D are in sequence in both strings). And we can calculate this by looking at relationships between each letter in the two strings, A and S.
#
# Here, I have a matrix with the letters of A on top and the letters of S on the left side:
#
# <img src='notebook_ims/matrix_1.png' width=40% />
#
# This starts out as a matrix that has as many columns and rows as letters in the strings S and O **+1** additional row and column, filled with zeros on the top and left sides. So, in this case, instead of a 2x4 matrix it is a 3x5.
#
# Now, we can fill this matrix up by breaking it into smaller LCS problems. For example, let's first look at the shortest substrings: the starting letter of A and S. We'll first ask, what is the Longest Common Subsequence between these two letters "A" and "B"?
#
# **Here, the answer is zero and we fill in the corresponding grid cell with that value.**
#
# <img src='notebook_ims/matrix_2.png' width=30% />
#
# Then, we ask the next question, what is the LCS between "AB" and "B"?
#
# **Here, we have a match, and can fill in the appropriate value 1**.
#
# <img src='notebook_ims/matrix_3_match.png' width=25% />
#
# If we continue, we get to a final matrix that looks as follows, with a **2** in the bottom right corner.
#
# <img src='notebook_ims/matrix_6_complete.png' width=25% />
#
# The final LCS will be that value **2** *normalized* by the number of n-grams in A. So, our normalized value is 2/4 = **0.5**.
#
# ### The matrix rules
#
# One thing to notice here is that, you can efficiently fill up this matrix one cell at a time. Each grid cell only depends on the values in the grid cells that are directly on top and to the left of it, or on the diagonal/top-left. The rules are as follows:
# * Start with a matrix that has one extra row and column of zeros.
# * As you traverse your string:
#     * If there is a match, fill that grid cell with the value to the top-left of that cell *plus* one. So, in our case, when we found a matching B-B, we added +1 to the value in the top-left of the matching cell, 0.
#     * If there is not a match, take the *maximum* value from either directly to the left or the top cell, and carry that value over to the non-match cell.
#
# <img src='notebook_ims/matrix_rules.png' width=50% />
#
# After completely filling the matrix, **the bottom-right cell will hold the non-normalized LCS value**.
#
# This matrix treatment can be applied to a set of words instead of letters. Your function should apply this to the words in two texts and return the normalized LCS value.

# %%
# Compute the normalized LCS given an answer text and a source text
def lcs_norm_word(answer_text, source_text):
    '''Computes the longest common subsequence of words in two texts; returns a normalized value.
       :param answer_text: The pre-processed text for an answer text
       :param source_text: The pre-processed text for an answer's associated source text
       :return: A normalized LCS value'''
    
    a_text = answer_text.split()
    s_text = source_text.split()
    
    n, m = len(a_text), len(s_text)
    mat = np.zeros((m+1, n+1))
    
    for i in range(m):
        row = i + 1
    
        for j in range(n):
            col = j + 1
            
            if s_text[i] == a_text[j]:
                # match
                mat[row, col] = mat[row-1, col-1] + 1
            else:
                # no match
                mat[row, col] = max(mat[row-1, col], mat[row, col-1])

    return mat[m, n] / n

# %%
lcs_norm_word("A B C D", "B D")
# Out:
# 0.5

# %% [markdown]
# ### Test cells
#
# Let's start by testing out your code on the example given in the initial description.
#
# In the below cell, we have specified strings A (answer text) and S (original source text). We know that these texts have 20 words in common and the submitted answer is 27 words long, so the normalized, longest common subsequence should be 20/27.

# %%
# Run the test scenario from above
# does your function return the expected value?

A = "i think pagerank is a link analysis algorithm used by google that uses a system of weights attached to each element of a hyperlinked set of documents"
S = "pagerank is a link analysis algorithm used by the google internet search engine that assigns a numerical weighting to each element of a hyperlinked set of documents"

# calculate LCS
lcs = lcs_norm_word(A, S)
print('LCS = ', lcs)


# expected value test
assert lcs==20/27., "Incorrect LCS value, expected about 0.7408, got "+str(lcs)

print('Test passed!')
# Out:
# LCS =  0.7407407407407407
# Test passed!

# %% [markdown]
# This next cell runs a more rigorous test.

# %%
# run test cell
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# test lcs implementation
# params: complete_df from before, and lcs_norm_word function
tests.test_lcs(complete_df, lcs_norm_word)
# Out:
# Tests Passed!

# %% [markdown]
# Finally, take a look at a few resultant values for `lcs_norm_word`. Just like before, you should see that higher values correspond to higher levels of plagiarism.

# %%
# test on your own
test_indices = range(5) # look at first few files

category_vals = []
lcs_norm_vals = []
# iterate through first few docs and calculate LCS
for i in test_indices:
    category_vals.append(complete_df.loc[i, 'Category'])
    # get texts to compare
    answer_text = complete_df.loc[i, 'Text'] 
    task = complete_df.loc[i, 'Task']
    # we know that source texts have Class = -1
    orig_rows = complete_df[(complete_df['Class'] == -1)]
    orig_row = orig_rows[(orig_rows['Task'] == task)]
    source_text = orig_row['Text'].values[0]
    
    # calculate lcs
    lcs_val = lcs_norm_word(answer_text, source_text)
    lcs_norm_vals.append(lcs_val)

# print out result, does it make sense?
print('Original category values: \n', category_vals)
print()
print('Normalized LCS values: \n', lcs_norm_vals)
# Out:
# Original category values:
#  [0, 3, 2, 1, 0]
#
# Normalized LCS values:
#  [0.1917808219178082, 0.8207547169811321, 0.8464912280701754, 0.3160621761658031, 0.24257425742574257]

# %% [markdown]
# ---
# # Create All Features
#
# Now that you've completed the feature calculation functions, it's time to actually create multiple features and decide on which ones to use in your final model! In the below cells, you're provided two helper functions to help you create multiple features and store those in a DataFrame, `features_df`.
#
# ### Creating multiple containment features
#
# Your completed `calculate_containment` function will be called in the next cell, which defines the helper function `create_containment_features`.
#
# > This function returns a list of containment features, calculated for a given `n` and for *all* files in a df (assumed to the the `complete_df`).
#
# For our original files, the containment value is set to a special value, -1.
#
# This function gives you the ability to easily create several containment features, of different n-gram lengths, for each of our text files.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Function returns a list of containment features, calculated for a given n 
# Should return a list of length 100 for all files in a complete_df
def create_containment_features(df, n, column_name=None):
    
    containment_values = []
    
    if(column_name==None):
        column_name = 'c_'+str(n) # c_1, c_2, .. c_n
    
    # iterates through dataframe rows
    for i in df.index:
        file = df.loc[i, 'File']
        # Computes features using calculate_containment function
        if df.loc[i,'Category'] > -1:
            c = calculate_containment(df, n, file)
            containment_values.append(c)
        # Sets value to -1 for original tasks 
        else:
            containment_values.append(-1)
    
    print(str(n)+'-gram containment features created!')
    return containment_values

# %% [markdown]
# ### Creating LCS features
#
# Below, your complete `lcs_norm_word` function is used to create a list of LCS features for all the answer files in a given DataFrame (again, this assumes you are passing in the `complete_df`. It assigns a special value for our original, source files, -1.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Function creates lcs feature and add it to the dataframe
def create_lcs_features(df, column_name='lcs_word'):
    
    lcs_values = []
    
    # iterate through files in dataframe
    for i in df.index:
        # Computes LCS_norm words feature using function above for answer tasks
        if df.loc[i,'Category'] > -1:
            # get texts to compare
            answer_text = df.loc[i, 'Text'] 
            task = df.loc[i, 'Task']
            # we know that source texts have Class = -1
            orig_rows = df[(df['Class'] == -1)]
            orig_row = orig_rows[(orig_rows['Task'] == task)]
            source_text = orig_row['Text'].values[0]

            # calculate lcs
            lcs = lcs_norm_word(answer_text, source_text)
            lcs_values.append(lcs)
        # Sets to -1 for original tasks 
        else:
            lcs_values.append(-1)

    print('LCS features created!')
    return lcs_values

# %% [markdown]
# ## EXERCISE: Create a features DataFrame by selecting an `ngram_range`
#
# The paper suggests calculating the following features: containment *1-gram to 5-gram* and *longest common subsequence*.
# > In this exercise, you can choose to create even more features, for example from *1-gram to 7-gram* containment features and *longest common subsequence*.
#
# You'll want to create at least 6 features to choose from as you think about which to give to your final, classification model. Defining and comparing at least 6 different features allows you to discard any features that seem redundant, and choose to use the best features for your final model!
#
# In the below cell **define an n-gram range**; these will be the n's you use to create n-gram containment features. The rest of the feature creation code is provided.

# %%
# Define an ngram range
ngram_range = range(1, 8)


# The following code may take a minute to run, depending on your ngram_range
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
features_list = []

# Create features in a features_df
all_features = np.zeros((len(ngram_range)+1, len(complete_df)))

# Calculate features for containment for ngrams in range
i=0
for n in ngram_range:
    column_name = 'c_'+str(n)
    features_list.append(column_name)
    # create containment features
    all_features[i]=np.squeeze(create_containment_features(complete_df, n))
    i+=1

# Calculate features for LCS_Norm Words 
features_list.append('lcs_word')
all_features[i]= np.squeeze(create_lcs_features(complete_df))

# create a features dataframe
features_df = pd.DataFrame(np.transpose(all_features), columns=features_list)

# Print all features/columns
print()
print('Features: ', features_list)
print()
# Out:
# common 1-grams: 86, answer_ngrams=216, containment 0.39814814814814814
# common 1-grams: 197, answer_ngrams=197, containment 1.0
# common 1-grams: 193, answer_ngrams=222, containment 0.8693693693693694
# common 1-grams: 111, answer_ngrams=187, containment 0.5935828877005348
# common 1-grams: 104, answer_ngrams=191, containment 0.5445026178010471
# common 1-grams: 86, answer_ngrams=261, containment 0.32950191570881227
# common 1-grams: 134, answer_ngrams=227, containment 0.5903083700440529
# common 1-grams: 225, answer_ngrams=294, containment 0.7653061224489796
# common 1-grams: 136, answer_ngrams=179, containment 0.7597765363128491
# common 1-grams: 199, answer_ngrams=225, containment 0.8844444444444445
# common 1-grams: 117, answer_ngrams=189, containment 0.6190476190476191
# common 1-grams: 96, answer_ngrams=186, containment 0.5161290322580645
# common 1-grams: 82, answer_ngrams=186, containment 0.44086021505376344
# common 1-grams: 143, answer_ngrams=146, containment 0.9794520547945206
# common 1-grams: 137, answer_ngrams=144, containment 0.9513888888888888
# common 1-grams: 166, answer_ngrams=170, containment 0.9764705882352941
# common 1-grams: 69, answer_ngrams=75, containment 0.92
# common 1-grams: 138, answer_ngrams=170, containment 0.8117647058823529
# common 1-grams: 15, answer_ngrams=34, containment 0.4411764705882353
# common 1-grams: 44, answer_ngrams=90, containment 0.4888888888888889
# common 1-grams: 271, answer_ngrams=273, containment 0.9926739926739927
# common 1-grams: 70, answer_ngrams=86, containment 0.813953488372093
# common 1-grams: 44, answer_ngrams=72, containment 0.6111111111111112
# common 1-grams: 26, answer_ngrams=63, containment 0.4126984126984127
# common 1-grams: 92, answer_ngrams=92, containment 1.0
# common 1-grams: 93, answer_ngrams=201, containment 0.4626865671641791
# common 1-grams: 123, answer_ngrams=194, containment 0.634020618556701
# common 1-grams: 123, answer_ngrams=211, containment 0.5829383886255924
# common 1-grams: 148, answer_ngrams=232, containment 0.6379310344827587
# common 1-grams: 111, answer_ngrams=191, containment 0.581151832460733
# common 1-grams: 66, answer_ngrams=157, containment 0.42038216560509556
# common 1-grams: 111, answer_ngrams=190, containment 0.5842105263157895
# common 1-grams: 163, answer_ngrams=237, containment 0.6877637130801688
# common 1-grams: 113, answer_ngrams=167, containment 0.6766467065868264
# common 1-grams: 230, answer_ngrams=299, containment 0.7692307692307693
# common 1-grams: 151, answer_ngrams=212, containment 0.7122641509433962
# common 1-grams: 160, answer_ngrams=254, containment 0.6299212598425197
# common 1-grams: 64, answer_ngrams=113, containment 0.5663716814159292
# common 1-grams: 65, answer_ngrams=135, containment 0.48148148148148145
# common 1-grams: 141, answer_ngrams=197, containment 0.7157360406091371
# common 1-grams: 87, answer_ngrams=262, containment 0.3320610687022901
# common 1-grams: 175, answer_ngrams=244, containment 0.7172131147540983
# common 1-grams: 202, answer_ngrams=230, containment 0.8782608695652174
# common 1-grams: 160, answer_ngrams=302, containment 0.5298013245033113
# common 1-grams: 119, answer_ngrams=208, containment 0.5721153846153846
# common 1-grams: 78, answer_ngrams=244, containment 0.319672131147541
# common 1-grams: 106, answer_ngrams=200, containment 0.53
# common 1-grams: 119, answer_ngrams=192, containment 0.6197916666666666
# common 1-grams: 212, answer_ngrams=230, containment 0.9217391304347826
# common 1-grams: 262, answer_ngrams=262, containment 1.0
# common 1-grams: 156, answer_ngrams=200, containment 0.78
# common 1-grams: 109, answer_ngrams=167, containment 0.6526946107784432
# common 1-grams: 99, answer_ngrams=223, containment 0.4439461883408072
# common 1-grams: 135, answer_ngrams=203, containment 0.6650246305418719
# common 1-grams: 150, answer_ngrams=206, containment 0.7281553398058253
# common 1-grams: 253, answer_ngrams=332, containment 0.7620481927710844
# common 1-grams: 143, answer_ngrams=151, containment 0.9470198675496688
# common 1-grams: 42, answer_ngrams=114, containment 0.3684210526315789
# common 1-grams: 81, answer_ngrams=152, containment 0.5328947368421053
# common 1-grams: 107, answer_ngrams=173, containment 0.6184971098265896
# common 1-grams: 99, answer_ngrams=194, containment 0.5103092783505154
# common 1-grams: 168, answer_ngrams=195, containment 0.8615384615384616
# common 1-grams: 201, answer_ngrams=321, containment 0.6261682242990654
# common 1-grams: 261, answer_ngrams=261, containment 1.0
# common 1-grams: 138, answer_ngrams=238, containment 0.5798319327731093
# common 1-grams: 81, answer_ngrams=199, containment 0.40703517587939697
# common 1-grams: 150, answer_ngrams=291, containment 0.5154639175257731
# common 1-grams: 121, answer_ngrams=207, containment 0.5845410628019324
# common 1-grams: 79, answer_ngrams=128, containment 0.6171875
# common 1-grams: 131, answer_ngrams=131, containment 1.0
# common 1-grams: 119, answer_ngrams=120, containment 0.9916666666666667
# common 1-grams: 98, answer_ngrams=178, containment 0.550561797752809
# common 1-grams: 39, answer_ngrams=93, containment 0.41935483870967744
# common 1-grams: 76, answer_ngrams=91, containment 0.8351648351648352
# common 1-grams: 89, answer_ngrams=96, containment 0.9270833333333334
# common 1-grams: 76, answer_ngrams=198, containment 0.3838383838383838
# common 1-grams: 104, answer_ngrams=211, containment 0.4928909952606635
# common 1-grams: 146, answer_ngrams=206, containment 0.7087378640776699
# common 1-grams: 158, answer_ngrams=183, containment 0.8633879781420765
# common 1-grams: 317, answer_ngrams=330, containment 0.9606060606060606
# common 1-grams: 275, answer_ngrams=275, containment 1.0
# common 1-grams: 97, answer_ngrams=158, containment 0.6139240506329114
# common 1-grams: 53, answer_ngrams=121, containment 0.4380165289256198
# common 1-grams: 250, answer_ngrams=257, containment 0.9727626459143969
# common 1-grams: 233, answer_ngrams=242, containment 0.9628099173553719
# common 1-grams: 146, answer_ngrams=199, containment 0.7336683417085427
# common 1-grams: 111, answer_ngrams=216, containment 0.5138888888888888
# common 1-grams: 98, answer_ngrams=236, containment 0.4152542372881356
# common 1-grams: 105, answer_ngrams=216, containment 0.4861111111111111
# common 1-grams: 202, answer_ngrams=239, containment 0.8451882845188284
# common 1-grams: 97, answer_ngrams=200, containment 0.485
# common 1-grams: 212, answer_ngrams=223, containment 0.9506726457399103
# common 1-grams: 113, answer_ngrams=205, containment 0.551219512195122
# common 1-grams: 69, answer_ngrams=191, containment 0.3612565445026178
# common 1-grams: 124, answer_ngrams=233, containment 0.5321888412017167
# 1-gram containment features created!
# common 2-grams: 17, answer_ngrams=215, containment 0.07906976744186046
# common 2-grams: 193, answer_ngrams=196, containment 0.9846938775510204
# common 2-grams: 159, answer_ngrams=221, containment 0.7194570135746606
# common 2-grams: 50, answer_ngrams=186, containment 0.26881720430107525
# common 2-grams: 22, answer_ngrams=190, containment 0.11578947368421053
# common 2-grams: 14, answer_ngrams=260, containment 0.05384615384615385
# common 2-grams: 34, answer_ngrams=226, containment 0.1504424778761062
# common 2-grams: 208, answer_ngrams=293, containment 0.7098976109215017
# common 2-grams: 90, answer_ngrams=178, containment 0.5056179775280899
# common 2-grams: 118, answer_ngrams=224, containment 0.5267857142857143
# common 2-grams: 47, answer_ngrams=188, containment 0.25
# common 2-grams: 13, answer_ngrams=185, containment 0.07027027027027027
# common 2-grams: 22, answer_ngrams=185, containment 0.11891891891891893
# common 2-grams: 133, answer_ngrams=145, containment 0.9172413793103448
# common 2-grams: 114, answer_ngrams=143, containment 0.7972027972027972
# common 2-grams: 145, answer_ngrams=169, containment 0.8579881656804734
# common 2-grams: 50, answer_ngrams=74, containment 0.6756756756756757
# common 2-grams: 94, answer_ngrams=169, containment 0.5562130177514792
# common 2-grams: 1, answer_ngrams=33, containment 0.030303030303030304
# common 2-grams: 6, answer_ngrams=89, containment 0.06741573033707865
# common 2-grams: 268, answer_ngrams=272, containment 0.9852941176470589
# common 2-grams: 57, answer_ngrams=85, containment 0.6705882352941176
# common 2-grams: 11, answer_ngrams=71, containment 0.15492957746478872
# common 2-grams: 7, answer_ngrams=62, containment 0.11290322580645161
# common 2-grams: 91, answer_ngrams=91, containment 1.0
# common 2-grams: 14, answer_ngrams=200, containment 0.07
# common 2-grams: 39, answer_ngrams=193, containment 0.20207253886010362
# common 2-grams: 61, answer_ngrams=210, containment 0.2904761904761905
# common 2-grams: 99, answer_ngrams=231, containment 0.42857142857142855
# common 2-grams: 27, answer_ngrams=190, containment 0.14210526315789473
# common 2-grams: 12, answer_ngrams=156, containment 0.07692307692307693
# common 2-grams: 27, answer_ngrams=189, containment 0.14285714285714285
# common 2-grams: 96, answer_ngrams=236, containment 0.4067796610169492
# common 2-grams: 53, answer_ngrams=166, containment 0.3192771084337349
# common 2-grams: 159, answer_ngrams=298, containment 0.5335570469798657
# common 2-grams: 80, answer_ngrams=211, containment 0.3791469194312796
# common 2-grams: 86, answer_ngrams=253, containment 0.33992094861660077
# common 2-grams: 17, answer_ngrams=112, containment 0.15178571428571427
# common 2-grams: 23, answer_ngrams=134, containment 0.17164179104477612
# common 2-grams: 51, answer_ngrams=196, containment 0.2602040816326531
# common 2-grams: 8, answer_ngrams=261, containment 0.03065134099616858
# common 2-grams: 88, answer_ngrams=243, containment 0.36213991769547327
# common 2-grams: 163, answer_ngrams=229, containment 0.7117903930131004
# common 2-grams: 107, answer_ngrams=301, containment 0.3554817275747508
# common 2-grams: 29, answer_ngrams=207, containment 0.14009661835748793
# common 2-grams: 10, answer_ngrams=243, containment 0.0411522633744856
# common 2-grams: 27, answer_ngrams=199, containment 0.135678391959799
# common 2-grams: 48, answer_ngrams=191, containment 0.2513089005235602
# common 2-grams: 193, answer_ngrams=229, containment 0.8427947598253275
# common 2-grams: 256, answer_ngrams=261, containment 0.9808429118773946
# common 2-grams: 131, answer_ngrams=199, containment 0.6582914572864321
# common 2-grams: 31, answer_ngrams=166, containment 0.18674698795180722
# common 2-grams: 34, answer_ngrams=222, containment 0.15315315315315314
# common 2-grams: 79, answer_ngrams=202, containment 0.3910891089108911
# common 2-grams: 63, answer_ngrams=205, containment 0.3073170731707317
# common 2-grams: 182, answer_ngrams=331, containment 0.5498489425981873
# common 2-grams: 101, answer_ngrams=150, containment 0.6733333333333333
# common 2-grams: 7, answer_ngrams=113, containment 0.061946902654867256
# common 2-grams: 15, answer_ngrams=151, containment 0.09933774834437085
# common 2-grams: 29, answer_ngrams=172, containment 0.1686046511627907
# common 2-grams: 18, answer_ngrams=193, containment 0.09326424870466321
# common 2-grams: 77, answer_ngrams=194, containment 0.39690721649484534
# common 2-grams: 149, answer_ngrams=320, containment 0.465625
# common 2-grams: 258, answer_ngrams=260, containment 0.9923076923076923
# common 2-grams: 28, answer_ngrams=237, containment 0.11814345991561181
# common 2-grams: 13, answer_ngrams=198, containment 0.06565656565656566
# common 2-grams: 27, answer_ngrams=290, containment 0.09310344827586207
# common 2-grams: 57, answer_ngrams=206, containment 0.2766990291262136
# common 2-grams: 43, answer_ngrams=127, containment 0.33858267716535434
# common 2-grams: 125, answer_ngrams=130, containment 0.9615384615384616
# common 2-grams: 115, answer_ngrams=119, containment 0.9663865546218487
# common 2-grams: 28, answer_ngrams=177, containment 0.15819209039548024
# common 2-grams: 7, answer_ngrams=92, containment 0.07608695652173914
# common 2-grams: 41, answer_ngrams=90, containment 0.45555555555555555
# common 2-grams: 66, answer_ngrams=95, containment 0.6947368421052632
# common 2-grams: 15, answer_ngrams=197, containment 0.07614213197969544
# common 2-grams: 12, answer_ngrams=210, containment 0.05714285714285714
# common 2-grams: 108, answer_ngrams=205, containment 0.526829268292683
# common 2-grams: 121, answer_ngrams=182, containment 0.6648351648351648
# common 2-grams: 303, answer_ngrams=329, containment 0.9209726443768997
# common 2-grams: 271, answer_ngrams=274, containment 0.9890510948905109
# common 2-grams: 21, answer_ngrams=157, containment 0.1337579617834395
# common 2-grams: 10, answer_ngrams=120, containment 0.08333333333333333
# common 2-grams: 240, answer_ngrams=256, containment 0.9375
# common 2-grams: 209, answer_ngrams=241, containment 0.8672199170124482
# common 2-grams: 70, answer_ngrams=198, containment 0.35353535353535354
# common 2-grams: 20, answer_ngrams=215, containment 0.09302325581395349
# common 2-grams: 24, answer_ngrams=235, containment 0.10212765957446808
# common 2-grams: 17, answer_ngrams=215, containment 0.07906976744186046
# common 2-grams: 130, answer_ngrams=238, containment 0.5462184873949579
# common 2-grams: 21, answer_ngrams=199, containment 0.10552763819095477
# common 2-grams: 195, answer_ngrams=222, containment 0.8783783783783784
# common 2-grams: 67, answer_ngrams=204, containment 0.3284313725490196
# common 2-grams: 6, answer_ngrams=190, containment 0.031578947368421054
# common 2-grams: 38, answer_ngrams=232, containment 0.16379310344827586
# 2-gram containment features created!
# common 3-grams: 2, answer_ngrams=214, containment 0.009345794392523364
# common 3-grams: 188, answer_ngrams=195, containment 0.9641025641025641
# common 3-grams: 135, answer_ngrams=220, containment 0.6136363636363636
# common 3-grams: 29, answer_ngrams=185, containment 0.15675675675675677
# common 3-grams: 6, answer_ngrams=189, containment 0.031746031746031744
# common 3-grams: 2, answer_ngrams=259, containment 0.007722007722007722
# common 3-grams: 8, answer_ngrams=225, containment 0.035555555555555556
# common 3-grams: 194, answer_ngrams=292, containment 0.6643835616438356
# common 3-grams: 70, answer_ngrams=177, containment 0.3954802259887006
# common 3-grams: 76, answer_ngrams=223, containment 0.34080717488789236
# common 3-grams: 21, answer_ngrams=187, containment 0.11229946524064172
# common 3-grams: 0, answer_ngrams=184, containment 0.0
# common 3-grams: 5, answer_ngrams=184, containment 0.02717391304347826
# common 3-grams: 126, answer_ngrams=144, containment 0.875
# common 3-grams: 96, answer_ngrams=142, containment 0.676056338028169
# common 3-grams: 126, answer_ngrams=168, containment 0.75
# common 3-grams: 41, answer_ngrams=73, containment 0.5616438356164384
# common 3-grams: 72, answer_ngrams=168, containment 0.42857142857142855
# common 3-grams: 0, answer_ngrams=32, containment 0.0
# common 3-grams: 0, answer_ngrams=88, containment 0.0
# common 3-grams: 266, answer_ngrams=271, containment 0.981549815498155
# common 3-grams: 54, answer_ngrams=84, containment 0.6428571428571429
# common 3-grams: 2, answer_ngrams=70, containment 0.02857142857142857
# common 3-grams: 2, answer_ngrams=61, containment 0.03278688524590164
# common 3-grams: 89, answer_ngrams=90, containment 0.9888888888888889
# common 3-grams: 2, answer_ngrams=199, containment 0.010050251256281407
# common 3-grams: 14, answer_ngrams=192, containment 0.07291666666666667
# common 3-grams: 43, answer_ngrams=209, containment 0.20574162679425836
# common 3-grams: 79, answer_ngrams=230, containment 0.34347826086956523
# common 3-grams: 7, answer_ngrams=189, containment 0.037037037037037035
# common 3-grams: 2, answer_ngrams=155, containment 0.012903225806451613
# common 3-grams: 2, answer_ngrams=188, containment 0.010638297872340425
# common 3-grams: 58, answer_ngrams=235, containment 0.24680851063829787
# common 3-grams: 31, answer_ngrams=165, containment 0.18787878787878787
# common 3-grams: 142, answer_ngrams=297, containment 0.4781144781144781
# common 3-grams: 41, answer_ngrams=210, containment 0.19523809523809524
# common 3-grams: 74, answer_ngrams=252, containment 0.29365079365079366
# common 3-grams: 4, answer_ngrams=111, containment 0.036036036036036036
# common 3-grams: 9, answer_ngrams=133, containment 0.06766917293233082
# common 3-grams: 16, answer_ngrams=195, containment 0.08205128205128205
# common 3-grams: 1, answer_ngrams=260, containment 0.0038461538461538464
# common 3-grams: 47, answer_ngrams=242, containment 0.19421487603305784
# common 3-grams: 139, answer_ngrams=228, containment 0.6096491228070176
# common 3-grams: 98, answer_ngrams=300, containment 0.32666666666666666
# common 3-grams: 6, answer_ngrams=206, containment 0.02912621359223301
# common 3-grams: 0, answer_ngrams=242, containment 0.0
# common 3-grams: 4, answer_ngrams=198, containment 0.020202020202020204
# common 3-grams: 19, answer_ngrams=190, containment 0.1
# common 3-grams: 177, answer_ngrams=228, containment 0.7763157894736842
# common 3-grams: 250, answer_ngrams=260, containment 0.9615384615384616
# common 3-grams: 125, answer_ngrams=198, containment 0.6313131313131313
# common 3-grams: 4, answer_ngrams=165, containment 0.024242424242424242
# common 3-grams: 10, answer_ngrams=221, containment 0.04524886877828054
# common 3-grams: 60, answer_ngrams=201, containment 0.29850746268656714
# common 3-grams: 28, answer_ngrams=204, containment 0.13725490196078433
# common 3-grams: 142, answer_ngrams=330, containment 0.4303030303030303
# common 3-grams: 72, answer_ngrams=149, containment 0.48322147651006714
# common 3-grams: 0, answer_ngrams=112, containment 0.0
# common 3-grams: 2, answer_ngrams=150, containment 0.013333333333333334
# common 3-grams: 8, answer_ngrams=171, containment 0.04678362573099415
# common 3-grams: 4, answer_ngrams=192, containment 0.020833333333333332
# common 3-grams: 35, answer_ngrams=193, containment 0.18134715025906736
# common 3-grams: 116, answer_ngrams=319, containment 0.36363636363636365
# common 3-grams: 255, answer_ngrams=259, containment 0.9845559845559846
# common 3-grams: 4, answer_ngrams=236, containment 0.01694915254237288
# common 3-grams: 3, answer_ngrams=197, containment 0.015228426395939087
# common 3-grams: 3, answer_ngrams=289, containment 0.010380622837370242
# common 3-grams: 28, answer_ngrams=205, containment 0.13658536585365855
# common 3-grams: 33, answer_ngrams=126, containment 0.2619047619047619
# common 3-grams: 119, answer_ngrams=129, containment 0.9224806201550387
# common 3-grams: 111, answer_ngrams=118, containment 0.940677966101695
# common 3-grams: 7, answer_ngrams=176, containment 0.03977272727272727
# common 3-grams: 3, answer_ngrams=91, containment 0.03296703296703297
# common 3-grams: 23, answer_ngrams=89, containment 0.25842696629213485
# common 3-grams: 48, answer_ngrams=94, containment 0.5106382978723404
# common 3-grams: 5, answer_ngrams=196, containment 0.025510204081632654
# common 3-grams: 0, answer_ngrams=209, containment 0.0
# common 3-grams: 91, answer_ngrams=204, containment 0.44607843137254904
# common 3-grams: 92, answer_ngrams=181, containment 0.5082872928176796
# common 3-grams: 294, answer_ngrams=328, containment 0.8963414634146342
# common 3-grams: 266, answer_ngrams=273, containment 0.9743589743589743
# common 3-grams: 3, answer_ngrams=156, containment 0.019230769230769232
# common 3-grams: 3, answer_ngrams=119, containment 0.025210084033613446
# common 3-grams: 230, answer_ngrams=255, containment 0.9019607843137255
# common 3-grams: 190, answer_ngrams=240, containment 0.7916666666666666
# common 3-grams: 40, answer_ngrams=197, containment 0.20304568527918782
# common 3-grams: 2, answer_ngrams=214, containment 0.009345794392523364
# common 3-grams: 6, answer_ngrams=234, containment 0.02564102564102564
# common 3-grams: 2, answer_ngrams=214, containment 0.009345794392523364
# common 3-grams: 95, answer_ngrams=237, containment 0.4008438818565401
# common 3-grams: 5, answer_ngrams=198, containment 0.025252525252525252
# common 3-grams: 182, answer_ngrams=221, containment 0.8235294117647058
# common 3-grams: 58, answer_ngrams=203, containment 0.2857142857142857
# common 3-grams: 0, answer_ngrams=189, containment 0.0
# common 3-grams: 18, answer_ngrams=231, containment 0.07792207792207792
# 3-gram containment features created!
# common 4-grams: 0, answer_ngrams=213, containment 0.0
# common 4-grams: 183, answer_ngrams=194, containment 0.9432989690721649
# common 4-grams: 113, answer_ngrams=219, containment 0.5159817351598174
# common 4-grams: 20, answer_ngrams=184, containment 0.10869565217391304
# common 4-grams: 1, answer_ngrams=188, containment 0.005319148936170213
# common 4-grams: 1, answer_ngrams=258, containment 0.003875968992248062
# common 4-grams: 1, answer_ngrams=224, containment 0.004464285714285714
# common 4-grams: 182, answer_ngrams=291, containment 0.6254295532646048
# common 4-grams: 54, answer_ngrams=176, containment 0.3068181818181818
# common 4-grams: 55, answer_ngrams=222, containment 0.24774774774774774
# common 4-grams: 14, answer_ngrams=186, containment 0.07526881720430108
# common 4-grams: 0, answer_ngrams=183, containment 0.0
# common 4-grams: 1, answer_ngrams=183, containment 0.00546448087431694
# common 4-grams: 119, answer_ngrams=143, containment 0.8321678321678322
# common 4-grams: 83, answer_ngrams=141, containment 0.5886524822695035
# common 4-grams: 110, answer_ngrams=167, containment 0.6586826347305389
# common 4-grams: 34, answer_ngrams=72, containment 0.4722222222222222
# common 4-grams: 58, answer_ngrams=167, containment 0.3473053892215569
# common 4-grams: 0, answer_ngrams=31, containment 0.0
# common 4-grams: 0, answer_ngrams=87, containment 0.0
# common 4-grams: 264, answer_ngrams=270, containment 0.9777777777777777
# common 4-grams: 53, answer_ngrams=83, containment 0.6385542168674698
# common 4-grams: 0, answer_ngrams=69, containment 0.0
# common 4-grams: 0, answer_ngrams=60, containment 0.0
# common 4-grams: 87, answer_ngrams=89, containment 0.9775280898876404
# common 4-grams: 1, answer_ngrams=198, containment 0.005050505050505051
# common 4-grams: 4, answer_ngrams=191, containment 0.020942408376963352
# common 4-grams: 28, answer_ngrams=208, containment 0.1346153846153846
# common 4-grams: 74, answer_ngrams=229, containment 0.3231441048034934
# common 4-grams: 1, answer_ngrams=188, containment 0.005319148936170213
# common 4-grams: 0, answer_ngrams=154, containment 0.0
# common 4-grams: 0, answer_ngrams=187, containment 0.0
# common 4-grams: 33, answer_ngrams=234, containment 0.14102564102564102
# common 4-grams: 23, answer_ngrams=164, containment 0.1402439024390244
# common 4-grams: 136, answer_ngrams=296, containment 0.4594594594594595
# common 4-grams: 26, answer_ngrams=209, containment 0.12440191387559808
# common 4-grams: 72, answer_ngrams=251, containment 0.2868525896414343
# common 4-grams: 1, answer_ngrams=110, containment 0.00909090909090909
# common 4-grams: 5, answer_ngrams=132, containment 0.03787878787878788
# common 4-grams: 4, answer_ngrams=194, containment 0.020618556701030927
# common 4-grams: 0, answer_ngrams=259, containment 0.0
# common 4-grams: 30, answer_ngrams=241, containment 0.12448132780082988
# common 4-grams: 120, answer_ngrams=227, containment 0.5286343612334802
# common 4-grams: 96, answer_ngrams=299, containment 0.3210702341137124
# common 4-grams: 0, answer_ngrams=205, containment 0.0
# common 4-grams: 0, answer_ngrams=241, containment 0.0
# common 4-grams: 1, answer_ngrams=197, containment 0.005076142131979695
# common 4-grams: 9, answer_ngrams=189, containment 0.047619047619047616
# common 4-grams: 162, answer_ngrams=227, containment 0.7136563876651982
# common 4-grams: 244, answer_ngrams=259, containment 0.9420849420849421
# common 4-grams: 122, answer_ngrams=197, containment 0.6192893401015228
# common 4-grams: 0, answer_ngrams=164, containment 0.0
# common 4-grams: 3, answer_ngrams=220, containment 0.013636363636363636
# common 4-grams: 46, answer_ngrams=200, containment 0.23
# common 4-grams: 13, answer_ngrams=203, containment 0.06403940886699508
# common 4-grams: 115, answer_ngrams=329, containment 0.3495440729483283
# common 4-grams: 55, answer_ngrams=148, containment 0.3716216216216216
# common 4-grams: 0, answer_ngrams=111, containment 0.0
# common 4-grams: 0, answer_ngrams=149, containment 0.0
# common 4-grams: 2, answer_ngrams=170, containment 0.011764705882352941
# common 4-grams: 3, answer_ngrams=191, containment 0.015706806282722512
# common 4-grams: 19, answer_ngrams=192, containment 0.09895833333333333
# common 4-grams: 92, answer_ngrams=318, containment 0.2893081761006289
# common 4-grams: 252, answer_ngrams=258, containment 0.9767441860465116
# common 4-grams: 1, answer_ngrams=235, containment 0.00425531914893617
# common 4-grams: 1, answer_ngrams=196, containment 0.00510204081632653
# common 4-grams: 0, answer_ngrams=288, containment 0.0
# common 4-grams: 18, answer_ngrams=204, containment 0.08823529411764706
# common 4-grams: 26, answer_ngrams=125, containment 0.208
# common 4-grams: 113, answer_ngrams=128, containment 0.8828125
# common 4-grams: 107, answer_ngrams=117, containment 0.9145299145299145
# common 4-grams: 2, answer_ngrams=175, containment 0.011428571428571429
# common 4-grams: 1, answer_ngrams=90, containment 0.011111111111111112
# common 4-grams: 10, answer_ngrams=88, containment 0.11363636363636363
# common 4-grams: 35, answer_ngrams=93, containment 0.3763440860215054
# common 4-grams: 3, answer_ngrams=195, containment 0.015384615384615385
# common 4-grams: 0, answer_ngrams=208, containment 0.0
# common 4-grams: 77, answer_ngrams=203, containment 0.3793103448275862
# common 4-grams: 71, answer_ngrams=180, containment 0.39444444444444443
# common 4-grams: 288, answer_ngrams=327, containment 0.8807339449541285
# common 4-grams: 261, answer_ngrams=272, containment 0.9595588235294118
# common 4-grams: 0, answer_ngrams=155, containment 0.0
# common 4-grams: 1, answer_ngrams=118, containment 0.00847457627118644
# common 4-grams: 220, answer_ngrams=254, containment 0.8661417322834646
# common 4-grams: 177, answer_ngrams=239, containment 0.7405857740585774
# common 4-grams: 24, answer_ngrams=196, containment 0.12244897959183673
# common 4-grams: 0, answer_ngrams=213, containment 0.0
# common 4-grams: 0, answer_ngrams=233, containment 0.0
# common 4-grams: 0, answer_ngrams=213, containment 0.0
# common 4-grams: 82, answer_ngrams=236, containment 0.3474576271186441
# common 4-grams: 1, answer_ngrams=197, containment 0.005076142131979695
# common 4-grams: 176, answer_ngrams=220, containment 0.8
# common 4-grams: 51, answer_ngrams=202, containment 0.2524752475247525
# common 4-grams: 0, answer_ngrams=188, containment 0.0
# common 4-grams: 9, answer_ngrams=230, containment 0.0391304347826087
# 4-gram containment features created!
# common 5-grams: 0, answer_ngrams=212, containment 0.0
# common 5-grams: 178, answer_ngrams=193, containment 0.9222797927461139
# common 5-grams: 98, answer_ngrams=218, containment 0.44954128440366975
# common 5-grams: 15, answer_ngrams=183, containment 0.08196721311475409
# common 5-grams: 0, answer_ngrams=187, containment 0.0
# common 5-grams: 0, answer_ngrams=257, containment 0.0
# common 5-grams: 0, answer_ngrams=223, containment 0.0
# common 5-grams: 171, answer_ngrams=290, containment 0.5896551724137931
# common 5-grams: 43, answer_ngrams=175, containment 0.24571428571428572
# common 5-grams: 40, answer_ngrams=221, containment 0.18099547511312217
# common 5-grams: 8, answer_ngrams=185, containment 0.043243243243243246
# common 5-grams: 0, answer_ngrams=182, containment 0.0
# common 5-grams: 0, answer_ngrams=182, containment 0.0
# common 5-grams: 112, answer_ngrams=142, containment 0.7887323943661971
# common 5-grams: 73, answer_ngrams=140, containment 0.5214285714285715
# common 5-grams: 96, answer_ngrams=166, containment 0.5783132530120482
# common 5-grams: 28, answer_ngrams=71, containment 0.39436619718309857
# common 5-grams: 47, answer_ngrams=166, containment 0.28313253012048195
# common 5-grams: 0, answer_ngrams=30, containment 0.0
# common 5-grams: 0, answer_ngrams=86, containment 0.0
# common 5-grams: 262, answer_ngrams=269, containment 0.9739776951672863
# common 5-grams: 52, answer_ngrams=82, containment 0.6341463414634146
# common 5-grams: 0, answer_ngrams=68, containment 0.0
# common 5-grams: 0, answer_ngrams=59, containment 0.0
# common 5-grams: 85, answer_ngrams=88, containment 0.9659090909090909
# common 5-grams: 0, answer_ngrams=197, containment 0.0
# common 5-grams: 1, answer_ngrams=190, containment 0.005263157894736842
# common 5-grams: 18, answer_ngrams=207, containment 0.08695652173913043
# common 5-grams: 70, answer_ngrams=228, containment 0.30701754385964913
# common 5-grams: 0, answer_ngrams=187, containment 0.0
# common 5-grams: 0, answer_ngrams=153, containment 0.0
# common 5-grams: 0, answer_ngrams=186, containment 0.0
# common 5-grams: 18, answer_ngrams=233, containment 0.07725321888412018
# common 5-grams: 18, answer_ngrams=163, containment 0.11042944785276074
# common 5-grams: 133, answer_ngrams=295, containment 0.45084745762711864
# common 5-grams: 18, answer_ngrams=208, containment 0.08653846153846154
# common 5-grams: 70, answer_ngrams=250, containment 0.28
# common 5-grams: 0, answer_ngrams=109, containment 0.0
# common 5-grams: 3, answer_ngrams=131, containment 0.022900763358778626
# common 5-grams: 1, answer_ngrams=193, containment 0.0051813471502590676
# common 5-grams: 0, answer_ngrams=258, containment 0.0
# common 5-grams: 19, answer_ngrams=240, containment 0.07916666666666666
# common 5-grams: 107, answer_ngrams=226, containment 0.47345132743362833
# common 5-grams: 94, answer_ngrams=298, containment 0.31543624161073824
# common 5-grams: 0, answer_ngrams=204, containment 0.0
# common 5-grams: 0, answer_ngrams=240, containment 0.0
# common 5-grams: 0, answer_ngrams=196, containment 0.0
# common 5-grams: 5, answer_ngrams=188, containment 0.026595744680851064
# common 5-grams: 148, answer_ngrams=226, containment 0.6548672566371682
# common 5-grams: 238, answer_ngrams=258, containment 0.9224806201550387
# common 5-grams: 119, answer_ngrams=196, containment 0.6071428571428571
# common 5-grams: 0, answer_ngrams=163, containment 0.0
# common 5-grams: 0, answer_ngrams=219, containment 0.0
# common 5-grams: 36, answer_ngrams=199, containment 0.18090452261306533
# common 5-grams: 7, answer_ngrams=202, containment 0.034653465346534656
# common 5-grams: 95, answer_ngrams=328, containment 0.2896341463414634
# common 5-grams: 42, answer_ngrams=147, containment 0.2857142857142857
# common 5-grams: 0, answer_ngrams=110, containment 0.0
# common 5-grams: 0, answer_ngrams=148, containment 0.0
# common 5-grams: 1, answer_ngrams=169, containment 0.005917159763313609
# common 5-grams: 2, answer_ngrams=190, containment 0.010526315789473684
# common 5-grams: 12, answer_ngrams=191, containment 0.06282722513089005
# common 5-grams: 71, answer_ngrams=317, containment 0.22397476340694006
# common 5-grams: 249, answer_ngrams=257, containment 0.9688715953307393
# common 5-grams: 0, answer_ngrams=234, containment 0.0
# common 5-grams: 0, answer_ngrams=195, containment 0.0
# common 5-grams: 0, answer_ngrams=287, containment 0.0
# common 5-grams: 10, answer_ngrams=203, containment 0.04926108374384237
# common 5-grams: 21, answer_ngrams=124, containment 0.1693548387096774
# common 5-grams: 107, answer_ngrams=127, containment 0.84251968503937
# common 5-grams: 103, answer_ngrams=116, containment 0.8879310344827587
# common 5-grams: 0, answer_ngrams=174, containment 0.0
# common 5-grams: 0, answer_ngrams=89, containment 0.0
# common 5-grams: 3, answer_ngrams=87, containment 0.034482758620689655
# common 5-grams: 27, answer_ngrams=92, containment 0.29347826086956524
# common 5-grams: 2, answer_ngrams=194, containment 0.010309278350515464
# common 5-grams: 0, answer_ngrams=207, containment 0.0
# common 5-grams: 65, answer_ngrams=202, containment 0.3217821782178218
# common 5-grams: 55, answer_ngrams=179, containment 0.30726256983240224
# common 5-grams: 282, answer_ngrams=326, containment 0.8650306748466258
# common 5-grams: 256, answer_ngrams=271, containment 0.9446494464944649
# common 5-grams: 0, answer_ngrams=154, containment 0.0
# common 5-grams: 0, answer_ngrams=117, containment 0.0
# common 5-grams: 210, answer_ngrams=253, containment 0.8300395256916996
# common 5-grams: 164, answer_ngrams=238, containment 0.6890756302521008
# common 5-grams: 14, answer_ngrams=195, containment 0.07179487179487179
# common 5-grams: 0, answer_ngrams=212, containment 0.0
# common 5-grams: 0, answer_ngrams=232, containment 0.0
# common 5-grams: 0, answer_ngrams=212, containment 0.0
# common 5-grams: 71, answer_ngrams=235, containment 0.3021276595744681
# common 5-grams: 0, answer_ngrams=196, containment 0.0
# common 5-grams: 171, answer_ngrams=219, containment 0.7808219178082192
# common 5-grams: 47, answer_ngrams=201, containment 0.23383084577114427
# common 5-grams: 0, answer_ngrams=187, containment 0.0
# common 5-grams: 4, answer_ngrams=229, containment 0.017467248908296942
# 5-gram containment features created!
# common 6-grams: 0, answer_ngrams=211, containment 0.0
# common 6-grams: 173, answer_ngrams=192, containment 0.9010416666666666
# common 6-grams: 83, answer_ngrams=217, containment 0.3824884792626728
# common 6-grams: 11, answer_ngrams=182, containment 0.06043956043956044
# common 6-grams: 0, answer_ngrams=186, containment 0.0
# common 6-grams: 0, answer_ngrams=256, containment 0.0
# common 6-grams: 0, answer_ngrams=222, containment 0.0
# common 6-grams: 160, answer_ngrams=289, containment 0.5536332179930796
# common 6-grams: 34, answer_ngrams=174, containment 0.19540229885057472
# common 6-grams: 33, answer_ngrams=220, containment 0.15
# common 6-grams: 4, answer_ngrams=184, containment 0.021739130434782608
# common 6-grams: 0, answer_ngrams=181, containment 0.0
# common 6-grams: 0, answer_ngrams=181, containment 0.0
# common 6-grams: 105, answer_ngrams=141, containment 0.7446808510638298
# common 6-grams: 63, answer_ngrams=139, containment 0.45323741007194246
# common 6-grams: 83, answer_ngrams=165, containment 0.503030303030303
# common 6-grams: 23, answer_ngrams=70, containment 0.32857142857142857
# common 6-grams: 39, answer_ngrams=165, containment 0.23636363636363636
# common 6-grams: 0, answer_ngrams=29, containment 0.0
# common 6-grams: 0, answer_ngrams=85, containment 0.0
# common 6-grams: 260, answer_ngrams=268, containment 0.9701492537313433
# common 6-grams: 51, answer_ngrams=81, containment 0.6296296296296297
# common 6-grams: 0, answer_ngrams=67, containment 0.0
# common 6-grams: 0, answer_ngrams=58, containment 0.0
# common 6-grams: 83, answer_ngrams=87, containment 0.9540229885057471
# common 6-grams: 0, answer_ngrams=196, containment 0.0
# common 6-grams: 0, answer_ngrams=189, containment 0.0
# common 6-grams: 11, answer_ngrams=206, containment 0.05339805825242718
# common 6-grams: 67, answer_ngrams=227, containment 0.29515418502202645
# common 6-grams: 0, answer_ngrams=186, containment 0.0
# common 6-grams: 0, answer_ngrams=152, containment 0.0
# common 6-grams: 0, answer_ngrams=185, containment 0.0
# common 6-grams: 11, answer_ngrams=232, containment 0.04741379310344827
# common 6-grams: 14, answer_ngrams=162, containment 0.08641975308641975
# common 6-grams: 130, answer_ngrams=294, containment 0.4421768707482993
# common 6-grams: 12, answer_ngrams=207, containment 0.057971014492753624
# common 6-grams: 68, answer_ngrams=249, containment 0.27309236947791166
# common 6-grams: 0, answer_ngrams=108, containment 0.0
# common 6-grams: 1, answer_ngrams=130, containment 0.007692307692307693
# common 6-grams: 0, answer_ngrams=192, containment 0.0
# common 6-grams: 0, answer_ngrams=257, containment 0.0
# common 6-grams: 14, answer_ngrams=239, containment 0.058577405857740586
# common 6-grams: 95, answer_ngrams=225, containment 0.4222222222222222
# common 6-grams: 92, answer_ngrams=297, containment 0.30976430976430974
# common 6-grams: 0, answer_ngrams=203, containment 0.0
# common 6-grams: 0, answer_ngrams=239, containment 0.0
# common 6-grams: 0, answer_ngrams=195, containment 0.0
# common 6-grams: 4, answer_ngrams=187, containment 0.0213903743315508
# common 6-grams: 135, answer_ngrams=225, containment 0.6
# common 6-grams: 232, answer_ngrams=257, containment 0.9027237354085603
# common 6-grams: 116, answer_ngrams=195, containment 0.5948717948717949
# common 6-grams: 0, answer_ngrams=162, containment 0.0
# common 6-grams: 0, answer_ngrams=218, containment 0.0
# common 6-grams: 29, answer_ngrams=198, containment 0.14646464646464646
# common 6-grams: 3, answer_ngrams=201, containment 0.014925373134328358
# common 6-grams: 80, answer_ngrams=327, containment 0.24464831804281345
# common 6-grams: 31, answer_ngrams=146, containment 0.21232876712328766
# common 6-grams: 0, answer_ngrams=109, containment 0.0
# common 6-grams: 0, answer_ngrams=147, containment 0.0
# common 6-grams: 0, answer_ngrams=168, containment 0.0
# common 6-grams: 1, answer_ngrams=189, containment 0.005291005291005291
# common 6-grams: 8, answer_ngrams=190, containment 0.042105263157894736
# common 6-grams: 54, answer_ngrams=316, containment 0.17088607594936708
# common 6-grams: 246, answer_ngrams=256, containment 0.9609375
# common 6-grams: 0, answer_ngrams=233, containment 0.0
# common 6-grams: 0, answer_ngrams=194, containment 0.0
# common 6-grams: 0, answer_ngrams=286, containment 0.0
# common 6-grams: 5, answer_ngrams=202, containment 0.024752475247524754
# common 6-grams: 17, answer_ngrams=123, containment 0.13821138211382114
# common 6-grams: 101, answer_ngrams=126, containment 0.8015873015873016
# common 6-grams: 99, answer_ngrams=115, containment 0.8608695652173913
# common 6-grams: 0, answer_ngrams=173, containment 0.0
# common 6-grams: 0, answer_ngrams=88, containment 0.0
# common 6-grams: 0, answer_ngrams=86, containment 0.0
# common 6-grams: 19, answer_ngrams=91, containment 0.2087912087912088
# common 6-grams: 1, answer_ngrams=193, containment 0.0051813471502590676
# common 6-grams: 0, answer_ngrams=206, containment 0.0
# common 6-grams: 55, answer_ngrams=201, containment 0.2736318407960199
# common 6-grams: 42, answer_ngrams=178, containment 0.23595505617977527
# common 6-grams: 276, answer_ngrams=325, containment 0.8492307692307692
# common 6-grams: 251, answer_ngrams=270, containment 0.9296296296296296
# common 6-grams: 0, answer_ngrams=153, containment 0.0
# common 6-grams: 0, answer_ngrams=116, containment 0.0
# common 6-grams: 200, answer_ngrams=252, containment 0.7936507936507936
# common 6-grams: 152, answer_ngrams=237, containment 0.6413502109704642
# common 6-grams: 7, answer_ngrams=194, containment 0.03608247422680412
# common 6-grams: 0, answer_ngrams=211, containment 0.0
# common 6-grams: 0, answer_ngrams=231, containment 0.0
# common 6-grams: 0, answer_ngrams=211, containment 0.0
# common 6-grams: 64, answer_ngrams=234, containment 0.27350427350427353
# common 6-grams: 0, answer_ngrams=195, containment 0.0
# common 6-grams: 166, answer_ngrams=218, containment 0.7614678899082569
# common 6-grams: 44, answer_ngrams=200, containment 0.22
# common 6-grams: 0, answer_ngrams=186, containment 0.0
# common 6-grams: 3, answer_ngrams=228, containment 0.013157894736842105
# 6-gram containment features created!
# common 7-grams: 0, answer_ngrams=210, containment 0.0
# common 7-grams: 168, answer_ngrams=191, containment 0.8795811518324608
# common 7-grams: 69, answer_ngrams=216, containment 0.3194444444444444
# common 7-grams: 8, answer_ngrams=181, containment 0.04419889502762431
# common 7-grams: 0, answer_ngrams=185, containment 0.0
# common 7-grams: 0, answer_ngrams=255, containment 0.0
# common 7-grams: 0, answer_ngrams=221, containment 0.0
# common 7-grams: 150, answer_ngrams=288, containment 0.5208333333333334
# common 7-grams: 26, answer_ngrams=173, containment 0.15028901734104047
# common 7-grams: 26, answer_ngrams=219, containment 0.1187214611872146
# common 7-grams: 2, answer_ngrams=183, containment 0.01092896174863388
# common 7-grams: 0, answer_ngrams=180, containment 0.0
# common 7-grams: 0, answer_ngrams=180, containment 0.0
# common 7-grams: 98, answer_ngrams=140, containment 0.7
# common 7-grams: 55, answer_ngrams=138, containment 0.39855072463768115
# common 7-grams: 71, answer_ngrams=164, containment 0.4329268292682927
# common 7-grams: 19, answer_ngrams=69, containment 0.2753623188405797
# common 7-grams: 32, answer_ngrams=164, containment 0.1951219512195122
# common 7-grams: 0, answer_ngrams=28, containment 0.0
# common 7-grams: 0, answer_ngrams=84, containment 0.0
# common 7-grams: 258, answer_ngrams=267, containment 0.9662921348314607
# common 7-grams: 50, answer_ngrams=80, containment 0.625
# common 7-grams: 0, answer_ngrams=66, containment 0.0
# common 7-grams: 0, answer_ngrams=57, containment 0.0
# common 7-grams: 81, answer_ngrams=86, containment 0.9418604651162791
# common 7-grams: 0, answer_ngrams=195, containment 0.0
# common 7-grams: 0, answer_ngrams=188, containment 0.0
# common 7-grams: 6, answer_ngrams=205, containment 0.02926829268292683
# common 7-grams: 64, answer_ngrams=226, containment 0.2831858407079646
# common 7-grams: 0, answer_ngrams=185, containment 0.0
# common 7-grams: 0, answer_ngrams=151, containment 0.0
# common 7-grams: 0, answer_ngrams=184, containment 0.0
# common 7-grams: 6, answer_ngrams=231, containment 0.025974025974025976
# common 7-grams: 12, answer_ngrams=161, containment 0.07453416149068323
# common 7-grams: 127, answer_ngrams=293, containment 0.4334470989761092
# common 7-grams: 8, answer_ngrams=206, containment 0.038834951456310676
# common 7-grams: 66, answer_ngrams=248, containment 0.2661290322580645
# common 7-grams: 0, answer_ngrams=107, containment 0.0
# common 7-grams: 0, answer_ngrams=129, containment 0.0
# common 7-grams: 0, answer_ngrams=191, containment 0.0
# common 7-grams: 0, answer_ngrams=256, containment 0.0
# common 7-grams: 10, answer_ngrams=238, containment 0.04201680672268908
# common 7-grams: 83, answer_ngrams=224, containment 0.3705357142857143
# common 7-grams: 90, answer_ngrams=296, containment 0.30405405405405406
# common 7-grams: 0, answer_ngrams=202, containment 0.0
# common 7-grams: 0, answer_ngrams=238, containment 0.0
# common 7-grams: 0, answer_ngrams=194, containment 0.0
# common 7-grams: 3, answer_ngrams=186, containment 0.016129032258064516
# common 7-grams: 123, answer_ngrams=224, containment 0.5491071428571429
# common 7-grams: 226, answer_ngrams=256, containment 0.8828125
# common 7-grams: 113, answer_ngrams=194, containment 0.5824742268041238
# common 7-grams: 0, answer_ngrams=161, containment 0.0
# common 7-grams: 0, answer_ngrams=217, containment 0.0
# common 7-grams: 23, answer_ngrams=197, containment 0.116751269035533
# common 7-grams: 1, answer_ngrams=200, containment 0.005
# common 7-grams: 66, answer_ngrams=326, containment 0.20245398773006135
# common 7-grams: 23, answer_ngrams=145, containment 0.15862068965517243
# common 7-grams: 0, answer_ngrams=108, containment 0.0
# common 7-grams: 0, answer_ngrams=146, containment 0.0
# common 7-grams: 0, answer_ngrams=167, containment 0.0
# common 7-grams: 0, answer_ngrams=188, containment 0.0
# common 7-grams: 4, answer_ngrams=189, containment 0.021164021164021163
# common 7-grams: 39, answer_ngrams=315, containment 0.12380952380952381
# common 7-grams: 243, answer_ngrams=255, containment 0.9529411764705882
# common 7-grams: 0, answer_ngrams=232, containment 0.0
# common 7-grams: 0, answer_ngrams=193, containment 0.0
# common 7-grams: 0, answer_ngrams=285, containment 0.0
# common 7-grams: 3, answer_ngrams=201, containment 0.014925373134328358
# common 7-grams: 13, answer_ngrams=122, containment 0.10655737704918032
# common 7-grams: 95, answer_ngrams=125, containment 0.76
# common 7-grams: 95, answer_ngrams=114, containment 0.8333333333333334
# common 7-grams: 0, answer_ngrams=172, containment 0.0
# common 7-grams: 0, answer_ngrams=87, containment 0.0
# common 7-grams: 0, answer_ngrams=85, containment 0.0
# common 7-grams: 12, answer_ngrams=90, containment 0.13333333333333333
# common 7-grams: 0, answer_ngrams=192, containment 0.0
# common 7-grams: 0, answer_ngrams=205, containment 0.0
# common 7-grams: 46, answer_ngrams=200, containment 0.23
# common 7-grams: 30, answer_ngrams=177, containment 0.1694915254237288
# common 7-grams: 270, answer_ngrams=324, containment 0.8333333333333334
# common 7-grams: 246, answer_ngrams=269, containment 0.9144981412639405
# common 7-grams: 0, answer_ngrams=152, containment 0.0
# common 7-grams: 0, answer_ngrams=115, containment 0.0
# common 7-grams: 191, answer_ngrams=251, containment 0.7609561752988048
# common 7-grams: 140, answer_ngrams=236, containment 0.5932203389830508
# common 7-grams: 5, answer_ngrams=193, containment 0.025906735751295335
# common 7-grams: 0, answer_ngrams=210, containment 0.0
# common 7-grams: 0, answer_ngrams=230, containment 0.0
# common 7-grams: 0, answer_ngrams=210, containment 0.0
# common 7-grams: 59, answer_ngrams=233, containment 0.2532188841201717
# common 7-grams: 0, answer_ngrams=194, containment 0.0
# common 7-grams: 161, answer_ngrams=217, containment 0.7419354838709677
# common 7-grams: 41, answer_ngrams=199, containment 0.20603015075376885
# common 7-grams: 0, answer_ngrams=185, containment 0.0
# common 7-grams: 2, answer_ngrams=227, containment 0.00881057268722467
# 7-gram containment features created!
# LCS features created!
#
# Features:  ['c_1', 'c_2', 'c_3', 'c_4', 'c_5', 'c_6', 'c_7', 'lcs_word']

# %%
# print some results 
features_df.head(10)
# Out:
#         c_1       c_2       c_3       c_4       c_5       c_6       c_7  \
# 0  0.398148  0.079070  0.009346  0.000000  0.000000  0.000000  0.000000
# 1  1.000000  0.984694  0.964103  0.943299  0.922280  0.901042  0.879581
# 2  0.869369  0.719457  0.613636  0.515982  0.449541  0.382488  0.319444
# 3  0.593583  0.268817  0.156757  0.108696  0.081967  0.060440  0.044199
# 4  0.544503  0.115789  0.031746  0.005319  0.000000  0.000000  0.000000
# 5  0.329502  0.053846  0.007722  0.003876  0.000000  0.000000  0.000000
# 6  0.590308  0.150442  0.035556  0.004464  0.000000  0.000000  0.000000
# 7  0.765306  0.709898  0.664384  0.625430  0.589655  0.553633  0.520833
# 8  0.759777  0.505618  0.395480  0.306818  0.245714  0.195402  0.150289
# 9  0.884444  0.526786  0.340807  0.247748  0.180995  0.150000  0.118721
#
#    lcs_word
# 0  0.191781
# 1  0.820755
# 2  0.846491
# 3  0.316062
# 4  0.242574
# 5  0.161172
# 6  0.301653
# 7  0.621711
# 8  0.484305
# 9  0.597458

# %% [markdown]
# ## Correlated Features
#
# You should use feature correlation across the *entire* dataset to determine which features are ***too*** **highly-correlated** with each other to include both features in a single model. For this analysis, you can use the *entire* dataset due to the small sample size we have.
#
# All of our features try to measure the similarity between two texts. Since our features are designed to measure similarity, it is expected that these features will be highly-correlated. Many classification models, for example a Naive Bayes classifier, rely on the assumption that features are *not* highly correlated; highly-correlated features may over-inflate the importance of a single feature.
#
# So, you'll want to choose your features based on which pairings have the lowest correlation. These correlation values range between 0 and 1; from low to high correlation, and are displayed in a [correlation matrix](https://www.displayr.com/what-is-a-correlation-matrix/), below.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Create correlation matrix for just Features to determine different models to test
corr_matrix = features_df.corr().abs().round(2)

# display shows all of a dataframe
display(corr_matrix)
# Out:
#            c_1   c_2   c_3   c_4   c_5   c_6   c_7  lcs_word
# c_1       1.00  0.94  0.90  0.89  0.88  0.87  0.87      0.97
# c_2       0.94  1.00  0.99  0.98  0.97  0.96  0.95      0.98
# c_3       0.90  0.99  1.00  1.00  0.99  0.98  0.98      0.97
# c_4       0.89  0.98  1.00  1.00  1.00  0.99  0.99      0.95
# c_5       0.88  0.97  0.99  1.00  1.00  1.00  1.00      0.95
# c_6       0.87  0.96  0.98  0.99  1.00  1.00  1.00      0.94
# c_7       0.87  0.95  0.98  0.99  1.00  1.00  1.00      0.93
# lcs_word  0.97  0.98  0.97  0.95  0.95  0.94  0.93      1.00

# %% [markdown]
# ## EXERCISE: Create selected train/test data
#
# Complete the `train_test_data` function below. This function should take in the following parameters:
# * `complete_df`: A DataFrame that contains all of our processed text data, file info, datatypes, and class labels
# * `features_df`: A DataFrame of all calculated features, such as containment for ngrams, n= 1-5, and lcs values for each text file listed in the `complete_df` (this was created in the above cells)
# * `selected_features`: A list of feature column names,  ex. `['c_1', 'lcs_word']`, which will be used to select the final features in creating train/test sets of data.
#
# It should return two tuples:
# * `(train_x, train_y)`, selected training features and their corresponding class labels (0/1)
# * `(test_x, test_y)`, selected training features and their corresponding class labels (0/1)
#
# ** Note: x and y should be arrays of feature values and numerical class labels, respectively; not DataFrames.**
#
# Looking at the above correlation matrix, you should decide on a **cutoff** correlation value, less than 1.0, to determine which sets of features are *too* highly-correlated to be included in the final training and test data. If you cannot find features that are less correlated than some cutoff value, it is suggested that you increase the number of features (longer n-grams) to choose from or use *only one or two* features in your final model to avoid introducing highly-correlated features.
#
# Recall that the `complete_df` has a `Datatype` column that indicates whether data should be `train` or `test` data; this should help you split the data appropriately.

# %%
mask_train = (complete_df["Datatype"] == "train")
mask_test = (complete_df["Datatype"] == "test")

# %%
features_df[mask_train]
# Out:
#          c_1       c_2       c_3       c_4       c_5       c_6       c_7  \
# 0   0.398148  0.079070  0.009346  0.000000  0.000000  0.000000  0.000000
# 2   0.869369  0.719457  0.613636  0.515982  0.449541  0.382488  0.319444
# 3   0.593583  0.268817  0.156757  0.108696  0.081967  0.060440  0.044199
# 4   0.544503  0.115789  0.031746  0.005319  0.000000  0.000000  0.000000
# 5   0.329502  0.053846  0.007722  0.003876  0.000000  0.000000  0.000000
# ..       ...       ...       ...       ...       ...       ...       ...
# 89  0.845188  0.546218  0.400844  0.347458  0.302128  0.273504  0.253219
# 90  0.485000  0.105528  0.025253  0.005076  0.000000  0.000000  0.000000
# 91  0.950673  0.878378  0.823529  0.800000  0.780822  0.761468  0.741935
# 92  0.551220  0.328431  0.285714  0.252475  0.233831  0.220000  0.206030
# 93  0.361257  0.031579  0.000000  0.000000  0.000000  0.000000  0.000000
#
#     lcs_word
# 0   0.191781
# 2   0.846491
# 3   0.316062
# 4   0.242574
# 5   0.161172
# ..       ...
# 89  0.643725
# 90  0.242718
# 91  0.839506
# 92  0.283019
# 93  0.161765
#
# [70 rows x 8 columns]

# %%
# Takes in dataframes and a list of selected features (column names) 
# and returns (train_x, train_y), (test_x, test_y)
def train_test_data(complete_df, features_df, selected_features):
    '''Gets selected training and test features from given dataframes, and 
       returns tuples for training and test features and their corresponding class labels.
       :param complete_df: A dataframe with all of our processed text data, datatypes, and labels
       :param features_df: A dataframe of all computed, similarity features
       :param selected_features: An array of selected features that correspond to certain columns in `features_df`
       :return: training and test features and labels: (train_x, train_y), (test_x, test_y)'''
    
    mask_train = (complete_df["Datatype"] == "train")
    mask_test = (complete_df["Datatype"] == "test")
    
    df_train = features_df[mask_train]
    df_test = features_df[mask_test]
    
    # train/test features, selected columns only
    train_x = df_train[selected_features].values
    test_x = df_test[selected_features].values
    
    # training class labels (0 or 1)
    train_y = complete_df["Class"][mask_train].values
    test_y = complete_df["Class"][mask_test].values
    
    
    return (train_x, train_y), (test_x, test_y)

# %% [markdown]
# ### Test cells
#
# Below, test out your implementation and create the final train/test data.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
test_selection = list(features_df)[:2] # first couple columns as a test
# test that the correct train/test data is created
(train_x, train_y), (test_x, test_y) = train_test_data(complete_df, features_df, test_selection)

# params: generated train/test data
tests.test_data_split(train_x, train_y, test_x, test_y)
# Out:
# Tests Passed!

# %% [markdown]
# ## EXERCISE: Select "good" features
#
# If you passed the test above, you can create your own train/test data, below.
#
# Define a list of features you'd like to include in your final mode, `selected_features`; this is a list of the features names you want to include.

# %%
# Select your list of features, this should be column names from features_df
# ex. ['c_1', 'lcs_word']
selected_features = ["c_1", "c_4", "c_7", "lcs_word"]

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

(train_x, train_y), (test_x, test_y) = train_test_data(complete_df, features_df, selected_features)

# check that division of samples seems correct
# these should add up to 95 (100 - 5 original files)
print('Training size: ', len(train_x))
print('Test size: ', len(test_x))
print()
print('Training df sample: \n', train_x[:10])
# Out:
# Training size:  70
# Test size:  25
#
# Training df sample:
#  [[0.39814815 0.         0.         0.19178082]
#  [0.86936937 0.51598174 0.31944444 0.84649123]
#  [0.59358289 0.10869565 0.0441989  0.31606218]
#  [0.54450262 0.00531915 0.         0.24257426]
#  [0.32950192 0.00387597 0.         0.16117216]
#  [0.59030837 0.00446429 0.         0.30165289]
#  [0.75977654 0.30681818 0.15028902 0.48430493]
#  [0.51612903 0.         0.         0.27083333]
#  [0.44086022 0.00546448 0.         0.22395833]
#  [0.97945205 0.83216783 0.7        0.9       ]]

# %% [markdown]
# ### Question 2: How did you decide on which features to include in your final model?

# %% [markdown]
# **Answer:**
#
# My final set of features is: c_1; c_4, c_7, lcs.  Here is my thinking process of how i got there.
#
# Initially i had created features_df using N-gram range up to 7, instead of 5. Since we anyway may drop correlated features, let's try bigger N to detect some evident copy-paste blocks.
#
# Then, i printed out the correlation matrix, but I noticed, that we had features_df with all 100 examples, including 5 original texts.

# %%
features_df.tail(10)
# Out:
#          c_1       c_2       c_3       c_4       c_5       c_6       c_7  \
# 90  0.485000  0.105528  0.025253  0.005076  0.000000  0.000000  0.000000
# 91  0.950673  0.878378  0.823529  0.800000  0.780822  0.761468  0.741935
# 92  0.551220  0.328431  0.285714  0.252475  0.233831  0.220000  0.206030
# 93  0.361257  0.031579  0.000000  0.000000  0.000000  0.000000  0.000000
# 94  0.532189  0.163793  0.077922  0.039130  0.017467  0.013158  0.008811
# 95 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 96 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 97 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 98 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 99 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
#
#     lcs_word
# 90  0.242718
# 91  0.839506
# 92  0.283019
# 93  0.161765
# 94  0.245833
# 95 -1.000000
# 96 -1.000000
# 97 -1.000000
# 98 -1.000000
# 99 -1.000000

# %% [markdown]
# Since all features have -1.0 values for all the features, this may pollute the correlation matrix a little bit. Indeed, let's compare correlation matrices for feature_df with and without 5 original texts:

# %%
features_df.corr()
# Out:
#                c_1       c_2       c_3       c_4       c_5       c_6  \
# c_1       1.000000  0.938579  0.903602  0.889210  0.880902  0.874829
# c_2       0.938579  1.000000  0.992575  0.982436  0.972602  0.962843
# c_3       0.903602  0.992575  1.000000  0.997022  0.991198  0.984007
# c_4       0.889210  0.982436  0.997022  1.000000  0.998323  0.994333
# c_5       0.880902  0.972602  0.991198  0.998323  1.000000  0.998749
# c_6       0.874829  0.962843  0.984007  0.994333  0.998749  1.000000
# c_7       0.869769  0.953091  0.975922  0.988795  0.995509  0.998959
# lcs_word  0.965716  0.983227  0.966634  0.954703  0.945042  0.935933
#
#                c_7  lcs_word
# c_1       0.869769  0.965716
# c_2       0.953091  0.983227
# c_3       0.975922  0.966634
# c_4       0.988795  0.954703
# c_5       0.995509  0.945042
# c_6       0.998959  0.935933
# c_7       1.000000  0.927349
# lcs_word  0.927349  1.000000

# %%
features_df[:95].corr()
# Out:
#                c_1       c_2       c_3       c_4       c_5       c_6  \
# c_1       1.000000  0.945632  0.897760  0.863563  0.836494  0.811895
# c_2       0.945632  1.000000  0.988742  0.970410  0.951455  0.932034
# c_3       0.897760  0.988742  1.000000  0.994722  0.984271  0.971256
# c_4       0.863563  0.970410  0.994722  1.000000  0.997027  0.989953
# c_5       0.836494  0.951455  0.984271  0.997027  1.000000  0.997796
# c_6       0.811895  0.932034  0.971256  0.989953  0.997796  1.000000
# c_7       0.789221  0.912361  0.956533  0.980094  0.992066  0.998157
# lcs_word  0.942365  0.975887  0.957375  0.934372  0.912450  0.890149
#
#                c_7  lcs_word
# c_1       0.789221  0.942365
# c_2       0.912361  0.975887
# c_3       0.956533  0.957375
# c_4       0.980094  0.934372
# c_5       0.992066  0.912450
# c_6       0.998157  0.890149
# c_7       1.000000  0.868497
# lcs_word  0.868497  1.000000

# %% [markdown]
# Indeed, values do change a little bit. Thus, from now on, we will always use 95 first rows to calculate correlation matrix.
#
# Then, to better understand the problem of correlated features, i read some articles. Examples:
#
# https://www.dezyre.com/recipes/drop-out-highly-correlated-features-in-python
# https://towardsdatascience.com/are-you-dropping-too-many-correlated-features-d1c96654abe6
#
# This gave me the understanding that there is no perfect method of dropping redundant features.
# And also, dropping even one feature will change the mean values of correlation matrix per feature, because the correlation value with the "worst" feature will not be now taken into account.
#
# That gave me an idea to drop features one by one, since in this example we have a small number of features, not tens or hundreds. Let's create a function that prints the correlation matrix as well as average correlation per feature, but after subtracting the diagonal (which has only 1.0 correlations between each feature and itself):

# %%
def show_corr_matrix(df):
    """
    Show correlation matrix for a given dataframe.
    Also show average correlation per feature, without the diagonal (self-correlations).
    """
    corr_mat = df.corr().round(3)
    ident = np.identity(corr_mat.shape[0])
    mean_corr = (corr_mat-ident).mean()
    print(f"Mean correlation per feature:\n{mean_corr}")
    return(corr_mat)

show_corr_matrix(features_df[:95])
# Out:
# Mean correlation per feature:
# c_1         0.760875
# c_2         0.834500
# c_3         0.843875
# c_4         0.841250
# c_5         0.833750
# c_6         0.823875
# c_7         0.812000
# lcs_word    0.809875
# dtype: float64
#             c_1    c_2    c_3    c_4    c_5    c_6    c_7  lcs_word
# c_1       1.000  0.946  0.898  0.864  0.836  0.812  0.789     0.942
# c_2       0.946  1.000  0.989  0.970  0.951  0.932  0.912     0.976
# c_3       0.898  0.989  1.000  0.995  0.984  0.971  0.957     0.957
# c_4       0.864  0.970  0.995  1.000  0.997  0.990  0.980     0.934
# c_5       0.836  0.951  0.984  0.997  1.000  0.998  0.992     0.912
# c_6       0.812  0.932  0.971  0.990  0.998  1.000  0.998     0.890
# c_7       0.789  0.912  0.957  0.980  0.992  0.998  1.000     0.868
# lcs_word  0.942  0.976  0.957  0.934  0.912  0.890  0.868     1.000

# %% [markdown]
# For classification algorithms to work well, we should avoid including features that have pairwise correlation close to 1.0, so by looking at the obtained results, we see very high correlation of 0.998 between each pair among features c_5, c_6, c_7. So we should keep only one feature of those 3. Looking at the average correlation per feature, we decide keeping c_7 and dropping c_5 and c_6.

# %%
df = features_df[:95]
to_drop = ["c_5", "c_6"]
show_corr_matrix(df.drop(columns=to_drop))
# Out:
# Mean correlation per feature:
# c_1         0.739833
# c_2         0.798833
# c_3         0.799333
# c_4         0.790500
# c_7         0.751000
# lcs_word    0.779500
# dtype: float64
#             c_1    c_2    c_3    c_4    c_7  lcs_word
# c_1       1.000  0.946  0.898  0.864  0.789     0.942
# c_2       0.946  1.000  0.989  0.970  0.912     0.976
# c_3       0.898  0.989  1.000  0.995  0.957     0.957
# c_4       0.864  0.970  0.995  1.000  0.980     0.934
# c_7       0.789  0.912  0.957  0.980  1.000     0.868
# lcs_word  0.942  0.976  0.957  0.934  0.868     1.000

# %% [markdown]
# Next big values we want to avoid are:
# * 0.995 correlation between c_3 and c_4;
# * 0.989 correlation between c_3 and c_2;
# * 0.980 correlation between c_4 and c_7;
# * 0.976 correlation between c_2 and lcs_word.
#
# So we will drop c_3 and one of (c_2, c_4).
# Let's probably keep c_4, as we then will have a nice set of (c_1, c_4, c_7) for short, average and long N-grams.

# %%
df = features_df[:95]
to_drop = ["c_5", "c_6", "c_3", "c_2"]
show_corr_matrix(df.drop(columns=to_drop))
# Out:
# Mean correlation per feature:
# c_1         0.64875
# c_4         0.69450
# c_7         0.65925
# lcs_word    0.68600
# dtype: float64
#             c_1    c_4    c_7  lcs_word
# c_1       1.000  0.864  0.789     0.942
# c_4       0.864  1.000  0.980     0.934
# c_7       0.789  0.980  1.000     0.868
# lcs_word  0.942  0.934  0.868     1.000

# %% [markdown]
# ---
# ## Creating Final Data Files
#
# Now, you are almost ready to move on to training a model in SageMaker!
#
# You'll want to access your train and test data in SageMaker and upload it to S3. In this project, SageMaker will expect the following format for your train/test data:
# * Training and test data should be saved in one `.csv` file each, ex `train.csv` and `test.csv`
# * These files should have class  labels in the first column and features in the rest of the columns
#
# This format follows the practice, outlined in the [SageMaker documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/cdf-training.html), which reads: "Amazon SageMaker requires that a CSV file doesn't have a header record and that the target variable [class label] is in the first column."
#
# ## EXERCISE: Create csv files
#
# Define a function that takes in x (features) and y (labels) and saves them to one `.csv` file at the path `data_dir/filename`.
#
# It may be useful to use pandas to merge your features and labels into one DataFrame and then convert that into a csv file. You can make sure to get rid of any incomplete rows, in a DataFrame, by using `dropna`.

# %%
def make_csv(x, y, filename, data_dir):
    '''Merges features and labels and converts them into one csv file with labels in the first column.
       :param x: Data features
       :param y: Data labels
       :param file_name: Name of csv file, ex. 'train.csv'
       :param data_dir: The directory where files will be saved
       '''
    # make data dir, if it does not exist
    if not os.path.exists(data_dir):
        os.makedirs(data_dir)
    
    
    # your code here
    df_x = pd.DataFrame(x)
    df_y = pd.DataFrame(y)
    df = pd.concat([df_y, df_x], axis=1)
    
    # nothing is returned, but a print statement indicates that the function has run
    file_path = os.path.join(data_dir, filename)
    df.to_csv(file_path, index=False, header=False)
    print('Path created: ' + file_path)

# %% [markdown]
# ### Test cells
#
# Test that your code produces the correct format for a `.csv` file, given some text features and labels.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
fake_x = [ [0.39814815, 0.0001, 0.19178082], 
           [0.86936937, 0.44954128, 0.84649123], 
           [0.44086022, 0., 0.22395833] ]

fake_y = [0, 1, 1]

make_csv(fake_x, fake_y, filename='to_delete.csv', data_dir='test_csv')

# read in and test dimensions
fake_df = pd.read_csv('test_csv/to_delete.csv', header=None)
# Out:
# Path created: test_csv/to_delete.csv

# %%
fake_df
# Out:
#    0         1         2         3
# 0  0  0.398148  0.000100  0.191781
# 1  1  0.869369  0.449541  0.846491
# 2  1  0.440860  0.000000  0.223958

# %%
# check shape
assert fake_df.shape==(3, 4), \
      'The file should have as many rows as data_points and as many columns as features+1 (for indices).'
# check that first column = labels
assert np.all(fake_df.iloc[:,0].values==fake_y), 'First column is not equal to the labels, fake_y.'
print('Tests passed!')
# Out:
# Tests passed!

# %%
# delete the test csv file, generated above
! rm -rf test_csv

# %% [markdown]
# If you've passed the tests above, run the following cell to create `train.csv` and `test.csv` files in a directory that you specify! This will save the data in a local directory. Remember the name of this directory because you will reference it again when uploading this data to S3.

# %%
# can change directory, if you want
data_dir = 'plagiarism_data'

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

make_csv(train_x, train_y, filename='train.csv', data_dir=data_dir)
make_csv(test_x, test_y, filename='test.csv', data_dir=data_dir)
# Out:
# Path created: plagiarism_data/train.csv
# Path created: plagiarism_data/test.csv

# %% [markdown]
# ## Up Next
#
# Now that you've done some feature engineering and created some training and test data, you are ready to train and deploy a plagiarism classification model. The next notebook will utilize SageMaker resources to train and test a model that you design.
